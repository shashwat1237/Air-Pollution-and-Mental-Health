# %%
import pandas as pd
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.linear_model import LinearRegression
import shap
from sklearn.metrics import mean_absolute_error, r2_score
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from imblearn.over_sampling import ADASYN
from sklearn.metrics import precision_recall_curve, auc, average_precision_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv("air-pollution.csv",header=0)
df.drop(["start_hour","start_month","start_day","end_year","end_month","end_hour","end_day","month","dayoftheweek","hour"],axis=1,inplace=True)

# %%
def cut_into_bins(column,num,bin_vertices=None):
    #print(column.describe())
    maxx=column.max()
    minn=column.min()
    step=(maxx-minn)/num
    
    bins=[minn+(i*step) for i in range(num)]+[maxx]
    print(bins,"duhifuhiufheufhu")
    if bin_vertices!=None:
        bins=bin_vertices
    #bins=[0,3.333,6.666,10]
    #print(bins,"bruh")
    labels=list(range(0,num))
    #print(bins,max(column),min(column),step)
    return pd.cut(column,bins=bins,labels=labels,include_lowest=True)
def oversampling(X_train,Y_train,num_bins,weights):
    together=pd.concat([X_train,Y_train],axis=1)
    together.info()
    #print(X_train.info())
    #print(Y_train.info())
    class_column=Y_train.columns.tolist()[0]
    class1=together[together[class_column]==0]
    class2=together[together[class_column]==1]
    class3=together[together[class_column]==2]

    classes=[together[together[class_column]==i] for i in range(num_bins)]
    lengths=[len(classes[i]) for i in range(num_bins)]
    max_length=max(lengths)
    mindex=lengths.index(max_length)

    for i in range(num_bins):
        if i!=mindex:
            classes[i]=resample(classes[i],
                               replace=True,
                               n_samples=max_length*weights[i],
                               random_state=42)

    
   

    mainn= pd.concat(classes)
    return mainn.drop(class_column,axis=1),mainn[class_column]
def remove_outliers_iqr(df,columns):
    # For each numeric column
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        if lower<0:
            lower=0
        upper = Q3 + 1.5 * IQR
        if upper>10:
            upper=10
        df = df[(df[col] >= lower) & (df[col] <= upper)]
    return df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 85 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID_Zenodo                        3348 non-null   int64
#  1   date_all                         3348 non-null   int64
#  2   year                             3348 non-null   int64
#  3   day                              3348 non-null   int64
#  4   mentalhealth_survey              3348 non-null   object
#  5   occurrence_mental                3280 non-null   float64
#  6   bienestar                        3273 non-null   float64
#  7   energia                          3207 non-null   float64
#  8   estres                           3173 non-null   float64
#  9   sueno                            3190 non-null   float64
#  10  horasfuera                       3231 non-null   float64
#  11  actividadfisica                  3232 non-null   object
#  12  ordenador                        3227 non-null   object
#  13  dieta                            3226 non-null   object
#  14  alcohol                          3222 non-null   object
#  15  drogas                           3227 non-null   object
#  16  bebida                           3225 non-null   object
#  17  enfermo                          3221 non-null   object
#  18  otrofactor                       3210 non-null   object
#  19  stroop_test                      3348 non-null   object
#  20  occurrence_stroop                3046 non-null   float64
#  21  mean_incongruent                 3046 non-null   float64
#  22  correct                          3046 non-null   float64
#  23  response_duration_ms             3046 non-null   float64
#  24  performance                      3046 non-null   float64
#  25  mean_congruent                   3046 non-null   float64
#  26  inhib_control                    3046 non-null   float64
#  27  z_performance                    3046 non-null   float64
#  28  z_mean_incongruent               3046 non-null   float64
#  29  z_inhib_control                  3046 non-null   float64
#  30  no2bcn_24h                       3348 non-null   float64
#  31  no2bcn_12h                       3348 non-null   float64
#  32  no2gps_24h                       3151 non-null   float64
#  33  no2gps_12h                       3146 non-null   float64
#  34  no2bcn_12h_x30                   3348 non-null   float64
#  35  no2bcn_24h_x30                   3348 non-null   float64
#  36  no2gps_12h_x30                   3151 non-null   float64
#  37  no2gps_24h_x30                   3151 non-null   float64
#  38  min_gps                          3242 non-null   float64
#  39  hour_gps                         3242 non-null   float64
#  40  pm25bcn                          3348 non-null   float64
#  41  BCμg                             3068 non-null   float64
#  42  sec_noise55_day                  2858 non-null   float64
#  43  sec_noise65_day                  2858 non-null   float64
#  44  sec_greenblue_day                2858 non-null   float64
#  45  hours_noise_55_day               2858 non-null   float64
#  46  hours_noise_65_day               2858 non-null   float64
#  47  hours_greenblue_day              2858 non-null   float64
#  48  tmean_24h                        3348 non-null   float64
#  49  tmean_12h                        3348 non-null   float64
#  50  humi_24h                         3348 non-null   float64
#  51  humi_12h                         3348 non-null   float64
#  52  pressure_24h                     3348 non-null   float64
#  53  pressure_12h                     3348 non-null   float64
#  54  precip_24h                       3348 non-null   float64
#  55  precip_12h                       3348 non-null   float64
#  56  precip_12h_binary                3348 non-null   int64
#  57  precip_24h_binary                3348 non-null   int64
#  58  maxwindspeed_24h                 3348 non-null   float64
#  59  maxwindspeed_12h                 3348 non-null   float64
#  60  noise_total_LDEN_55              3048 non-null   float64
#  61  access_greenbluespaces_300mbuff  3048 non-null   object
#  62  µgm3                             3018 non-null   float64
#  63  incidence_cat                    3018 non-null   object
#  64  start_year                       3018 non-null   float64
#  65  Totaltime                        3018 non-null   float64
#  66  Totaltime_estimated              3018 non-null   object
#  67  Houron                           3018 non-null   object
#  68  Houroff                          3018 non-null   object
#  69  age_yrs                          3172 non-null   float64
#  70  yearbirth                        3172 non-null   float64
#  71  smoke                            3000 non-null   object
#  72  psycho                           2964 non-null   object
#  73  gender                           3338 non-null   object
#  74  district                         3183 non-null   object
#  75  education                        3033 non-null   object
#  76  covid_work                       3313 non-null   object
#  77  covid_mood                       3174 non-null   object
#  78  covid_sleep                      3159 non-null   object
#  79  covid_espacios                   3150 non-null   object
#  80  covid_aire                       3150 non-null   object
#  81  covid_motor                      3095 non-null   object
#  82  covid_electric                   3046 non-null   object
#  83  covid_bikewalk                   3136 non-null   object
#  84  covid_public_trans               3136 non-null   object
# dtypes: float64(50), int64(6), object(29)
# memory usage: 2.2+ MB

# %%
df.dropna(inplace=True)

# %%
object_df=df.select_dtypes(include=["object"]).copy()
object_columns=list(object_df.columns)
#print(object_df.columns)
les=[LabelEncoder() for _ in range(len(object_columns))]
#print(object_df.columns)
index=0
while index<len(object_columns):
    column_name=object_columns[index]
    #print(object_df.columns)
    values_for_label=les[index].fit_transform(object_df[column_name].apply(lambda x:x.lower()))
    if len([i for i in list(values_for_label)])>10:
        object_df.drop(columns=[column_name],inplace=True)
        index+=1
        continue
    object_df[object_columns[index]]=values_for_label
    index+=1

# %%
numerical_df=df.select_dtypes(exclude=["object"])
numerical_df=pd.concat([numerical_df,object_df])

# %%
numerical_df.head()
# Out:
#     ID_Zenodo  date_all    year   day  occurrence_mental  bienestar  energia  \
# 3       115.0   22222.0  2020.0   3.0               14.0        3.0      2.0
# 9       212.0   22247.0  2020.0  28.0                4.0        9.0      9.0
# 11      104.0   22208.0  2020.0  20.0                1.0        6.0      6.0
# 12      216.0   22247.0  2020.0  28.0                2.0        8.0      8.0
# 14       94.0   22213.0  2020.0  25.0               12.0        8.0      4.0
#
#     estres  sueno  horasfuera  ...  precip_12h_binary  precip_24h_binary  \
# 3      5.0    2.0         5.0  ...                0.0                0.0
# 9      1.0    9.0         5.0  ...                1.0                1.0
# 11     7.0    9.0        11.0  ...                0.0                0.0
# 12     1.0    3.0         2.0  ...                1.0                1.0
# 14     2.0    8.0         1.0  ...                0.0                0.0
#
#     maxwindspeed_24h  maxwindspeed_12h  noise_total_LDEN_55   µgm3  \
# 3                0.0               0.0                  1.0  15.72
# 9                4.0               2.0                  0.0  37.50
# 11               0.0               0.0                  1.0  41.97
# 12               4.0               2.0                  1.0  33.49
# 14               0.0               0.0                  1.0  33.47
#
#     start_year  Totaltime  age_yrs  yearbirth
# 3       2020.0     168.00     29.0     1991.0
# 9       2020.0     179.40     28.0     1992.0
# 11      2020.0     168.17     50.0     1970.0
# 12      2020.0     205.00     25.0     1995.0
# 14      2020.0     170.58     35.0     1985.0
#
# [5 rows x 56 columns]

# %%
numerical_df.select_dtypes(include=["float"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3188 entries, 3 to 3310
# Data columns (total 56 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Zenodo             1594 non-null   float64
#  1   date_all              1594 non-null   float64
#  2   year                  1594 non-null   float64
#  3   day                   1594 non-null   float64
#  4   occurrence_mental     1594 non-null   float64
#  5   bienestar             1594 non-null   float64
#  6   energia               1594 non-null   float64
#  7   estres                1594 non-null   float64
#  8   sueno                 1594 non-null   float64
#  9   horasfuera            1594 non-null   float64
#  10  occurrence_stroop     1594 non-null   float64
#  11  mean_incongruent      1594 non-null   float64
#  12  correct               1594 non-null   float64
#  13  response_duration_ms  1594 non-null   float64
#  14  performance           1594 non-null   float64
#  15  mean_congruent        1594 non-null   float64
#  16  inhib_control         1594 non-null   float64
#  17  z_performance         1594 non-null   float64
#  18  z_mean_incongruent    1594 non-null   float64
#  19  z_inhib_control       1594 non-null   float64
#  20  no2bcn_24h            1594 non-null   float64
#  21  no2bcn_12h            1594 non-null   float64
#  22  no2gps_24h            1594 non-null   float64
#  23  no2gps_12h            1594 non-null   float64
#  24  no2bcn_12h_x30        1594 non-null   float64
#  25  no2bcn_24h_x30        1594 non-null   float64
#  26  no2gps_12h_x30        1594 non-null   float64
#  27  no2gps_24h_x30        1594 non-null   float64
#  28  min_gps               1594 non-null   float64
#  29  hour_gps              1594 non-null   float64
#  30  pm25bcn               1594 non-null   float64
#  31  BCμg                  1594 non-null   float64
#  32  sec_noise55_day       1594 non-null   float64
#  33  sec_noise65_day       1594 non-null   float64
#  34  sec_greenblue_day     1594 non-null   float64
#  35  hours_noise_55_day    1594 non-null   float64
#  36  hours_noise_65_day    1594 non-null   float64
#  37  hours_greenblue_day   1594 non-null   float64
#  38  tmean_24h             1594 non-null   float64
#  39  tmean_12h             1594 non-null   float64
#  40  humi_24h              1594 non-null   float64
#  41  humi_12h              1594 non-null   float64
#  42  pressure_24h          1594 non-null   float64
#  43  pressure_12h          1594 non-null   float64
#  44  precip_24h            1594 non-null   float64
#  45  precip_12h            1594 non-null   float64
#  46  precip_12h_binary     1594 non-null   float64
#  47  precip_24h_binary     1594 non-null   float64
#  48  maxwindspeed_24h      1594 non-null   float64
#  49  maxwindspeed_12h      1594 non-null   float64
#  50  noise_total_LDEN_55   1594 non-null   float64
#  51  µgm3                  1594 non-null   float64
#  52  start_year            1594 non-null   float64
#  53  Totaltime             1594 non-null   float64
#  54  age_yrs               1594 non-null   float64
#  55  yearbirth             1594 non-null   float64
# dtypes: float64(56)
# memory usage: 1.4 MB

# %%
def func(num):
    try:
        return int(num)
    except:
        return num
numerical_df[["age_yrs","yearbirth","Totaltime","start_year"]]=numerical_df[["age_yrs","yearbirth","Totaltime","start_year"]].apply(func)

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3188 entries, 3 to 3310
# Data columns (total 56 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Zenodo             1594 non-null   float64
#  1   date_all              1594 non-null   float64
#  2   year                  1594 non-null   float64
#  3   day                   1594 non-null   float64
#  4   occurrence_mental     1594 non-null   float64
#  5   bienestar             1594 non-null   float64
#  6   energia               1594 non-null   float64
#  7   estres                1594 non-null   float64
#  8   sueno                 1594 non-null   float64
#  9   horasfuera            1594 non-null   float64
#  10  occurrence_stroop     1594 non-null   float64
#  11  mean_incongruent      1594 non-null   float64
#  12  correct               1594 non-null   float64
#  13  response_duration_ms  1594 non-null   float64
#  14  performance           1594 non-null   float64
#  15  mean_congruent        1594 non-null   float64
#  16  inhib_control         1594 non-null   float64
#  17  z_performance         1594 non-null   float64
#  18  z_mean_incongruent    1594 non-null   float64
#  19  z_inhib_control       1594 non-null   float64
#  20  no2bcn_24h            1594 non-null   float64
#  21  no2bcn_12h            1594 non-null   float64
#  22  no2gps_24h            1594 non-null   float64
#  23  no2gps_12h            1594 non-null   float64
#  24  no2bcn_12h_x30        1594 non-null   float64
#  25  no2bcn_24h_x30        1594 non-null   float64
#  26  no2gps_12h_x30        1594 non-null   float64
#  27  no2gps_24h_x30        1594 non-null   float64
#  28  min_gps               1594 non-null   float64
#  29  hour_gps              1594 non-null   float64
#  30  pm25bcn               1594 non-null   float64
#  31  BCμg                  1594 non-null   float64
#  32  sec_noise55_day       1594 non-null   float64
#  33  sec_noise65_day       1594 non-null   float64
#  34  sec_greenblue_day     1594 non-null   float64
#  35  hours_noise_55_day    1594 non-null   float64
#  36  hours_noise_65_day    1594 non-null   float64
#  37  hours_greenblue_day   1594 non-null   float64
#  38  tmean_24h             1594 non-null   float64
#  39  tmean_12h             1594 non-null   float64
#  40  humi_24h              1594 non-null   float64
#  41  humi_12h              1594 non-null   float64
#  42  pressure_24h          1594 non-null   float64
#  43  pressure_12h          1594 non-null   float64
#  44  precip_24h            1594 non-null   float64
#  45  precip_12h            1594 non-null   float64
#  46  precip_12h_binary     1594 non-null   float64
#  47  precip_24h_binary     1594 non-null   float64
#  48  maxwindspeed_24h      1594 non-null   float64
#  49  maxwindspeed_12h      1594 non-null   float64
#  50  noise_total_LDEN_55   1594 non-null   float64
#  51  µgm3                  1594 non-null   float64
#  52  start_year            1594 non-null   float64
#  53  Totaltime             1594 non-null   float64
#  54  age_yrs               1594 non-null   float64
#  55  yearbirth             1594 non-null   float64
# dtypes: float64(56)
# memory usage: 1.4 MB

# %%
numerical_df["bienestar"].describe()
# Out:
# count    1594.000000
# mean        7.216437
# std         1.721021
# min         0.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max        10.000000
# Name: bienestar, dtype: float64

# %%
numerical_df.corr()["bienestar"].sort_values(key=abs,ascending=False).head(20)
# Out:
# bienestar              1.000000
# energia                0.672855
# sueno                  0.393371
# estres                -0.346724
# no2gps_12h            -0.113428
# no2bcn_12h            -0.113231
# no2bcn_12h_x30        -0.113231
# no2gps_24h            -0.102820
# no2gps_12h_x30        -0.102820
# no2gps_24h_x30        -0.102820
# no2bcn_24h_x30        -0.085564
# no2bcn_24h            -0.085564
# BCμg                  -0.084776
# hours_greenblue_day    0.076608
# sec_greenblue_day      0.076608
# year                   0.061721
# start_year             0.061721
# date_all               0.057162
# tmean_24h             -0.055411
# correct                0.054348
# Name: bienestar, dtype: float64

# %%
sns.barplot(x=cut_into_bins(numerical_df["no2bcn_12h"],5),y=numerical_df["bienestar"])
# Out:
# [np.float64(5.238095238095238), np.float64(21.19563492063492), np.float64(37.1531746031746), np.float64(53.11071428571428), np.float64(69.06825396825396), np.float64(85.02579365079364)] duhifuhiufheufhu
# <Axes: xlabel='no2bcn_12h', ylabel='bienestar'>

# %%
numerical_df=numerical_df.drop("ID_Zenodo",axis=1)
correlation=numerical_df.corr()
correlation=correlation.reset_index()
correlation_melted=correlation.melt(id_vars="index",var_name="col",value_name="val")
correlation_melted=correlation_melted[correlation_melted["index"]!=correlation_melted["col"]]

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3188 entries, 3 to 3310
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1594 non-null   float64
#  1   year                  1594 non-null   float64
#  2   day                   1594 non-null   float64
#  3   occurrence_mental     1594 non-null   float64
#  4   bienestar             1594 non-null   float64
#  5   energia               1594 non-null   float64
#  6   estres                1594 non-null   float64
#  7   sueno                 1594 non-null   float64
#  8   horasfuera            1594 non-null   float64
#  9   occurrence_stroop     1594 non-null   float64
#  10  mean_incongruent      1594 non-null   float64
#  11  correct               1594 non-null   float64
#  12  response_duration_ms  1594 non-null   float64
#  13  performance           1594 non-null   float64
#  14  mean_congruent        1594 non-null   float64
#  15  inhib_control         1594 non-null   float64
#  16  z_performance         1594 non-null   float64
#  17  z_mean_incongruent    1594 non-null   float64
#  18  z_inhib_control       1594 non-null   float64
#  19  no2bcn_24h            1594 non-null   float64
#  20  no2bcn_12h            1594 non-null   float64
#  21  no2gps_24h            1594 non-null   float64
#  22  no2gps_12h            1594 non-null   float64
#  23  no2bcn_12h_x30        1594 non-null   float64
#  24  no2bcn_24h_x30        1594 non-null   float64
#  25  no2gps_12h_x30        1594 non-null   float64
#  26  no2gps_24h_x30        1594 non-null   float64
#  27  min_gps               1594 non-null   float64
#  28  hour_gps              1594 non-null   float64
#  29  pm25bcn               1594 non-null   float64
#  30  BCμg                  1594 non-null   float64
#  31  sec_noise55_day       1594 non-null   float64
#  32  sec_noise65_day       1594 non-null   float64
#  33  sec_greenblue_day     1594 non-null   float64
#  34  hours_noise_55_day    1594 non-null   float64
#  35  hours_noise_65_day    1594 non-null   float64
#  36  hours_greenblue_day   1594 non-null   float64
#  37  tmean_24h             1594 non-null   float64
#  38  tmean_12h             1594 non-null   float64
#  39  humi_24h              1594 non-null   float64
#  40  humi_12h              1594 non-null   float64
#  41  pressure_24h          1594 non-null   float64
#  42  pressure_12h          1594 non-null   float64
#  43  precip_24h            1594 non-null   float64
#  44  precip_12h            1594 non-null   float64
#  45  precip_12h_binary     1594 non-null   float64
#  46  precip_24h_binary     1594 non-null   float64
#  47  maxwindspeed_24h      1594 non-null   float64
#  48  maxwindspeed_12h      1594 non-null   float64
#  49  noise_total_LDEN_55   1594 non-null   float64
#  50  µgm3                  1594 non-null   float64
#  51  start_year            1594 non-null   float64
#  52  Totaltime             1594 non-null   float64
#  53  age_yrs               1594 non-null   float64
#  54  yearbirth             1594 non-null   float64
# dtypes: float64(55)
# memory usage: 1.4 MB

# %%
correlation_melted.head()
# Out:
#                index       col       val
# 1               year  date_all  0.665819
# 2                day  date_all  0.031729
# 3  occurrence_mental  date_all  0.220259
# 4          bienestar  date_all  0.057162
# 5            energia  date_all  0.052727

# %%
s=set()
columns=list(numerical_df.columns)
for i in range(len(columns)):
    c1=columns[i]
    for j in range(i+1,len(columns)):
        
        s.add(c1+columns[j])

#correlation_melted=correlation_melted[(correlation_melted["index"]+correlation_melted["col"]) in s]
correlation_melted=correlation_melted[(correlation_melted["index"]+correlation_melted["col"]).isin(s)]
correlation_melted=correlation_melted.sort_values(by="val",ascending=False,key=abs)

# %%
to_print=correlation_melted.head(200)

for index in range(len(to_print)):
    row=to_print.iloc[index]
    print(row["index"],row["col"],row["val"])
# Out:
# min_gps hour_gps 1.0000000000000009
# sec_noise55_day hours_noise_55_day 1.0000000000000007
# age_yrs yearbirth -1.0000000000000002
# year start_year 1.0
# no2gps_12h_x30 no2gps_24h_x30 1.0
# mean_incongruent response_duration_ms 1.0
# sec_noise65_day hours_noise_65_day 0.9999999999999994
# sec_greenblue_day hours_greenblue_day 0.9999999999999994
# no2bcn_24h no2bcn_24h_x30 0.9999999999999991
# no2gps_24h no2gps_24h_x30 0.9999999999999961
# no2gps_24h no2gps_12h_x30 0.9999999999999961
# no2bcn_12h no2bcn_12h_x30 0.9999999999999954
# pressure_24h pressure_12h 0.9864351979018311
# occurrence_mental occurrence_stroop 0.9784493073750425
# tmean_24h tmean_12h 0.9625947334290155
# precip_12h maxwindspeed_12h 0.9521364839688422
# performance z_performance 0.9479732159653254
# inhib_control z_inhib_control 0.9460809989137213
# humi_24h humi_12h 0.9333606317453959
# z_performance z_mean_incongruent -0.9282973095182534
# mean_incongruent z_mean_incongruent 0.9084945953696532
# response_duration_ms z_mean_incongruent 0.9084945953696532
# mean_incongruent performance -0.9026579631405806
# response_duration_ms performance -0.9026579631405806
# no2bcn_12h_x30 no2bcn_24h_x30 0.8845251478061281
# no2bcn_12h no2bcn_24h_x30 0.8845251477428203
# no2bcn_24h no2bcn_12h_x30 0.8845251453149062
# no2bcn_24h no2bcn_12h 0.884525145251598
# performance z_mean_incongruent -0.8785437007673171
# no2bcn_24h no2gps_12h_x30 0.8774039086094134
# no2bcn_24h no2gps_24h_x30 0.8774039086094134
# no2bcn_24h_x30 no2gps_24h_x30 0.877403907325814
# no2bcn_24h_x30 no2gps_12h_x30 0.877403907325814
# no2bcn_24h no2gps_24h 0.8774039070884503
# no2gps_24h no2bcn_24h_x30 0.8774039058048536
# no2bcn_12h no2gps_12h 0.8743205716361923
# no2gps_12h no2bcn_12h_x30 0.8743205708927096
# no2gps_24h no2gps_12h 0.8723290333140283
# no2gps_12h no2gps_12h_x30 0.8723290312491125
# no2gps_12h no2gps_24h_x30 0.8723290312491125
# no2bcn_12h BCμg 0.8453441937752468
# no2bcn_12h_x30 BCμg 0.8453441889824769
# response_duration_ms z_performance -0.8428116279298626
# mean_incongruent z_performance -0.8428116279298626
# no2bcn_12h no2gps_24h 0.8217028080155839
# no2bcn_12h no2gps_24h_x30 0.8217028073323382
# no2bcn_12h no2gps_12h_x30 0.8217028073323382
# no2gps_24h no2bcn_12h_x30 0.8217028062107921
# no2bcn_12h_x30 no2gps_12h_x30 0.8217028055275467
# no2bcn_12h_x30 no2gps_24h_x30 0.8217028055275467
# no2bcn_24h_x30 BCμg 0.8208751143798099
# no2bcn_24h BCμg 0.8208751074232982
# precip_24h maxwindspeed_24h 0.8083925078537015
# maxwindspeed_24h maxwindspeed_12h 0.8013334698396203
# precip_12h maxwindspeed_24h 0.7634418789160817
# response_duration_ms mean_congruent 0.7596021904933538
# mean_incongruent mean_congruent 0.7596021904933538
# no2gps_12h no2bcn_24h_x30 0.7278619682605232
# no2bcn_24h no2gps_12h 0.7278619668966039
# precip_12h_binary precip_24h_binary 0.7256445224375087
# no2gps_12h_x30 BCμg 0.7172792690575799
# no2gps_24h_x30 BCμg 0.7172792690575799
# no2gps_24h BCμg 0.7172792683101353
# pm25bcn BCμg 0.7096244316866703
# performance mean_congruent -0.7053887537381127
# no2gps_12h BCμg 0.7046476819558797
# date_all tmean_12h -0.6900212152760219
# mean_congruent z_mean_incongruent 0.6844217802198992
# date_all tmean_24h -0.6766984300777674
# bienestar energia 0.6728551592596358
# min_gps hours_noise_55_day 0.6680696062546944
# hour_gps hours_noise_55_day 0.6680696062546934
# min_gps sec_noise55_day 0.6680696062546934
# hour_gps sec_noise55_day 0.6680696062546928
# date_all start_year 0.6658192037264313
# date_all year 0.6658192037264313
# hours_noise_55_day hours_noise_65_day 0.6562236938748847
# sec_noise65_day hours_noise_55_day 0.6562236938748837
# sec_noise55_day hours_noise_65_day 0.6562236938748837
# sec_noise55_day sec_noise65_day 0.656223693874883
# precip_24h precip_12h 0.6530461795139167
# mean_congruent z_performance -0.6444086927725226
# precip_24h maxwindspeed_12h 0.6353808200486541
# precip_24h precip_12h_binary 0.6287946928778501
# no2bcn_24h_x30 pm25bcn 0.6183242234642972
# no2bcn_24h pm25bcn 0.6183242196630383
# precip_24h_binary maxwindspeed_24h 0.5939968941355116
# precip_12h_binary maxwindspeed_12h 0.5927095052845864
# precip_24h precip_24h_binary 0.5824714634142786
# no2bcn_12h pm25bcn 0.5660019472784427
# no2bcn_12h_x30 pm25bcn 0.5660019453055829
# no2gps_24h pm25bcn 0.5440125638056647
# no2gps_24h_x30 pm25bcn 0.5440125629280227
# no2gps_12h_x30 pm25bcn 0.5440125629280227
# precip_12h_binary maxwindspeed_24h 0.5387579978194053
# precip_12h precip_12h_binary 0.5253016954699757
# humi_12h precip_12h_binary 0.5148774503778526
# no2gps_12h pm25bcn 0.48589006501247484
# humi_24h precip_12h_binary 0.48533295091690426
# humi_24h precip_24h_binary 0.4772758951767052
# z_performance age_yrs -0.4714614855524968
# z_performance yearbirth 0.47146148555249606
# z_mean_incongruent age_yrs 0.46508217900354154
# z_mean_incongruent yearbirth -0.4650821790035412
# min_gps hours_noise_65_day 0.44908109357178694
# min_gps sec_noise65_day 0.44908109357178677
# hour_gps hours_noise_65_day 0.44908109357178677
# hour_gps sec_noise65_day 0.44908109357178555
# humi_12h precip_24h_binary 0.4382952300489727
# performance yearbirth 0.43523375363252187
# performance age_yrs -0.4352337536325218
# BCμg humi_12h 0.4338007439412314
# pm25bcn pressure_24h 0.43053211980909845
# precip_24h_binary maxwindspeed_12h 0.43009640590640624
# pm25bcn pressure_12h 0.42051180495115986
# response_duration_ms yearbirth -0.4176351650477447
# mean_incongruent yearbirth -0.4176351650477447
# response_duration_ms age_yrs 0.4176351650477435
# mean_incongruent age_yrs 0.4176351650477435
# humi_24h precip_24h 0.41531914384291363
# mean_congruent yearbirth -0.4144462884545518
# mean_congruent age_yrs 0.41444628845455017
# energia sueno 0.4133189779485028
# BCμg pressure_24h 0.41241657561922634
# BCμg humi_24h 0.41057037844201355
# mean_incongruent inhib_control 0.4088279311416908
# response_duration_ms inhib_control 0.4088279311416908
# humi_12h maxwindspeed_12h 0.3944837678670925
# bienestar sueno 0.3933707217943962
# BCμg pressure_12h 0.3900426292727954
# min_gps hours_greenblue_day 0.38995148231469046
# min_gps sec_greenblue_day 0.3899514823146895
# hour_gps hours_greenblue_day 0.38995148231468935
# hour_gps sec_greenblue_day 0.3899514823146891
# humi_24h maxwindspeed_24h 0.38518010887168525
# humi_12h precip_24h 0.38314759714354013
# precip_12h precip_24h_binary 0.3811822979449247
# inhib_control z_mean_incongruent 0.37937779215037226
# z_mean_incongruent z_inhib_control 0.3740025734383809
# no2bcn_24h_x30 pressure_24h 0.3686166004910306
# no2bcn_24h pressure_24h 0.36861659857116347
# humi_12h maxwindspeed_24h 0.36316148604220433
# humi_12h precip_12h 0.3623108744371901
# no2bcn_12h humi_12h 0.35488545567032964
# no2bcn_12h_x30 humi_12h 0.3548854531032635
# response_duration_ms z_inhib_control 0.3546995781377768
# mean_incongruent z_inhib_control 0.3546995781377768
# humi_24h maxwindspeed_12h 0.34683459479422
# bienestar estres -0.34672385657128113
# no2bcn_24h_x30 pressure_12h 0.34390823704582996
# no2bcn_24h pressure_12h 0.34390823480812005
# performance inhib_control -0.34135014768694477
# z_performance z_inhib_control -0.339056416743753
# inhib_control z_performance -0.3386615672702142
# performance z_inhib_control -0.32937821710180337
# humi_24h precip_12h 0.3244321616737366
# no2bcn_12h humi_24h 0.32267373265391525
# no2bcn_12h_x30 humi_24h 0.3226737305892122
# no2bcn_12h_x30 pressure_24h 0.3144953786938601
# no2bcn_12h pressure_24h 0.3144953728772013
# no2bcn_24h_x30 humi_24h 0.31086641669161574
# no2bcn_24h humi_24h 0.3108664157246842
# no2bcn_24h humi_12h 0.31046371288835517
# no2bcn_24h_x30 humi_12h 0.31046371165433573
# no2gps_24h pressure_24h 0.3079782220031445
# no2gps_12h_x30 pressure_24h 0.3079782215479188
# no2gps_24h_x30 pressure_24h 0.3079782215479188
# no2gps_12h pressure_24h 0.3067379758810149
# pm25bcn precip_24h -0.30551400570364323
# pm25bcn precip_24h_binary -0.30207338563033026
# mean_congruent z_inhib_control -0.3014654046873259
# no2bcn_12h_x30 pressure_12h 0.2956505207743286
# no2bcn_12h pressure_12h 0.2956505151496646
# no2gps_12h pressure_12h 0.2925801637485921
# pm25bcn maxwindspeed_24h -0.28707427040342737
# no2gps_24h pressure_12h 0.28557714438955556
# no2gps_24h_x30 pressure_12h 0.28557714370686055
# no2gps_12h_x30 pressure_12h 0.28557714370686055
# mean_congruent inhib_control -0.28300493963131845
# occurrence_stroop performance 0.275947343178266
# occurrence_mental performance 0.2661199485448539
# pressure_12h precip_12h_binary -0.2653467461820368
# occurrence_stroop response_duration_ms -0.2652723485775554
# occurrence_stroop mean_incongruent -0.2652723485775554
# estres no2bcn_12h 0.2643248644425177
# estres no2bcn_12h_x30 0.264324861367131
# occurrence_stroop mean_congruent -0.2641693359193173
# occurrence_mental response_duration_ms -0.2546691399540566
# occurrence_mental mean_incongruent -0.2546691399540566
# estres no2gps_12h 0.25279960383417954
# occurrence_mental mean_congruent -0.2504819888749914
# pressure_12h precip_24h_binary -0.24913874876579784
# no2gps_24h_x30 precip_24h -0.247982970962355
# no2gps_12h_x30 precip_24h -0.247982970962355
# no2gps_24h precip_24h -0.24798297062921965
# correct performance 0.24615398122464172
# no2bcn_24h precip_24h -0.24555911137045414
# no2bcn_24h_x30 precip_24h -0.2455591081417526
# start_year yearbirth -0.24345383829538778
# year yearbirth -0.24345383829538778

# %%
columns=list(numerical_df.columns)
#numerical_df.drop(columns=["energia","estres","sueno"],inplace=True)

# %%
numerical_df.corr()
# Out:
#                       date_all      year       day  occurrence_mental  \
# date_all              1.000000  0.665819  0.031729           0.220259
# year                  0.665819  1.000000 -0.043715           0.015168
# day                   0.031729 -0.043715  1.000000           0.174679
# occurrence_mental     0.220259  0.015168  0.174679           1.000000
# bienestar             0.057162  0.061721  0.047862           0.017940
# energia               0.052727  0.071931  0.056245           0.043134
# estres               -0.073653 -0.064639 -0.048786          -0.107374
# sueno                 0.017791  0.074608  0.047973           0.018185
# horasfuera           -0.051322 -0.054866 -0.023086          -0.061342
# occurrence_stroop     0.206963  0.012571  0.170914           0.978449
# mean_incongruent      0.071857  0.203487 -0.000862          -0.254669
# correct              -0.024525 -0.021971 -0.009541           0.053961
# response_duration_ms  0.071857  0.203487 -0.000862          -0.254669
# performance          -0.057174 -0.211453  0.003529           0.266120
# mean_congruent        0.030165  0.159326  0.007366          -0.250482
# inhib_control         0.063639  0.076516 -0.011608          -0.024086
# z_performance        -0.118465 -0.221963 -0.044692          -0.021292
# z_mean_incongruent    0.137035  0.224699  0.052204           0.028536
# z_inhib_control       0.062911  0.067547 -0.000839           0.003110
# no2bcn_24h            0.126159 -0.021137  0.101258           0.174202
# no2bcn_12h            0.180790 -0.021757  0.071041           0.150790
# no2gps_24h            0.176373 -0.014210  0.082585           0.184972
# no2gps_12h            0.199532 -0.049773  0.064304           0.169194
# no2bcn_12h_x30        0.180790 -0.021757  0.071041           0.150790
# no2bcn_24h_x30        0.126159 -0.021137  0.101258           0.174202
# no2gps_12h_x30        0.176373 -0.014210  0.082585           0.184972
# no2gps_24h_x30        0.176373 -0.014210  0.082585           0.184972
# min_gps               0.015836  0.019462  0.007739           0.050052
# hour_gps              0.015836  0.019462  0.007739           0.050052
# pm25bcn               0.185628  0.098803  0.111927           0.233276
# BCμg                  0.132961 -0.029657  0.071291           0.189202
# sec_noise55_day      -0.029525 -0.041043 -0.001323           0.048823
# sec_noise65_day      -0.070843 -0.059778 -0.000102          -0.022906
# sec_greenblue_day     0.074467  0.053121 -0.016952           0.012566
# hours_noise_55_day   -0.029525 -0.041043 -0.001323           0.048823
# hours_noise_65_day   -0.070843 -0.059778 -0.000102          -0.022906
# hours_greenblue_day   0.074467  0.053121 -0.016952           0.012566
# tmean_24h            -0.676698 -0.204212  0.104370          -0.200995
# tmean_12h            -0.690021 -0.210934  0.109884          -0.164512
# humi_24h              0.222697  0.064038  0.056492          -0.037946
# humi_12h              0.217962  0.070522  0.084541          -0.032585
# pressure_24h          0.027956 -0.028672  0.196292           0.227469
# pressure_12h          0.028126 -0.023083  0.215568           0.229832
# precip_24h           -0.033794 -0.052179  0.117674          -0.123504
# precip_12h           -0.095383 -0.023942  0.005072          -0.069967
# precip_12h_binary     0.026134 -0.009644  0.072477          -0.119389
# precip_24h_binary     0.041038  0.025409  0.013391          -0.173590
# maxwindspeed_24h     -0.114160 -0.055029  0.000333          -0.112342
# maxwindspeed_12h     -0.091535 -0.040256  0.036089          -0.094289
# noise_total_LDEN_55  -0.001121 -0.010552 -0.018343           0.053280
# µgm3                 -0.080063 -0.051819 -0.020276          -0.038903
# start_year            0.665819  1.000000 -0.043715           0.015168
# Totaltime             0.031419 -0.005073  0.042935           0.010184
# age_yrs               0.078506  0.243454  0.027752           0.068618
# yearbirth            -0.078506 -0.243454 -0.027752          -0.068618
#
#                       bienestar   energia    estres     sueno  horasfuera  \
# date_all               0.057162  0.052727 -0.073653  0.017791   -0.051322
# year                   0.061721  0.071931 -0.064639  0.074608   -0.054866
# day                    0.047862  0.056245 -0.048786  0.047973   -0.023086
# occurrence_mental      0.017940  0.043134 -0.107374  0.018185   -0.061342
# bienestar              1.000000  0.672855 -0.346724  0.393371   -0.050137
# energia                0.672855  1.000000 -0.160992  0.413319    0.005536
# estres                -0.346724 -0.160992  1.000000 -0.202156    0.150409
# sueno                  0.393371  0.413319 -0.202156  1.000000   -0.088921
# horasfuera            -0.050137  0.005536  0.150409 -0.088921    1.000000
# occurrence_stroop      0.025074  0.051859 -0.116117  0.029329   -0.055821
# mean_incongruent      -0.021160  0.028901  0.115846 -0.037998   -0.000632
# correct                0.054348  0.054409 -0.014477  0.001754   -0.003257
# response_duration_ms  -0.021160  0.028901  0.115846 -0.037998   -0.000632
# performance            0.041306 -0.019906 -0.135680  0.042857   -0.018653
# mean_congruent        -0.009570  0.051726  0.091677 -0.029987    0.003443
# inhib_control         -0.017777 -0.029962  0.042197 -0.013959   -0.005763
# z_performance          0.033679 -0.037983 -0.105482  0.032935    0.003815
# z_mean_incongruent    -0.014068  0.050042  0.086562 -0.022487   -0.028594
# z_inhib_control       -0.015347 -0.029359  0.028199 -0.002442   -0.012516
# no2bcn_24h            -0.085564 -0.059550  0.218061 -0.101965    0.122243
# no2bcn_12h            -0.113231 -0.069831  0.264325 -0.142126    0.142276
# no2gps_24h            -0.102820 -0.076183  0.232706 -0.106650    0.068351
# no2gps_12h            -0.113428 -0.068993  0.252800 -0.128206    0.083814
# no2bcn_12h_x30        -0.113231 -0.069831  0.264325 -0.142126    0.142276
# no2bcn_24h_x30        -0.085564 -0.059550  0.218061 -0.101965    0.122243
# no2gps_12h_x30        -0.102820 -0.076183  0.232706 -0.106650    0.068351
# no2gps_24h_x30        -0.102820 -0.076183  0.232706 -0.106650    0.068351
# min_gps                0.017187  0.057766 -0.036786 -0.001806    0.025535
# hour_gps               0.017187  0.057766 -0.036786 -0.001806    0.025535
# pm25bcn               -0.028902 -0.022544  0.059320 -0.039949    0.022425
# BCμg                  -0.084776 -0.054706  0.176905 -0.101462    0.097411
# sec_noise55_day       -0.017634  0.013639  0.023961 -0.057542   -0.002389
# sec_noise65_day       -0.007394 -0.018712  0.019077 -0.043463    0.050606
# sec_greenblue_day      0.076608  0.080215 -0.019963 -0.037544    0.106219
# hours_noise_55_day    -0.017634  0.013639  0.023961 -0.057542   -0.002389
# hours_noise_65_day    -0.007394 -0.018712  0.019077 -0.043463    0.050606
# hours_greenblue_day    0.076608  0.080215 -0.019963 -0.037544    0.106219
# tmean_24h             -0.055411 -0.034947  0.045238  0.029499    0.022655
# tmean_12h             -0.043695 -0.022330  0.030916  0.044458    0.031464
# humi_24h              -0.053614 -0.044853  0.047202 -0.010439   -0.001695
# humi_12h              -0.051629 -0.034280  0.079172 -0.023916    0.015928
# pressure_24h          -0.020424 -0.002345  0.047135 -0.005147   -0.019245
# pressure_12h          -0.011451  0.005110  0.035604  0.001696   -0.029845
# precip_24h             0.045333  0.015122 -0.050041  0.034845   -0.029364
# precip_12h             0.019375 -0.002046 -0.041460  0.006077   -0.023547
# precip_12h_binary      0.015061 -0.010369 -0.044012  0.020007   -0.009988
# precip_24h_binary     -0.003791 -0.007857 -0.018109  0.020275   -0.001775
# maxwindspeed_24h       0.036290  0.024149 -0.062502  0.022286   -0.024327
# maxwindspeed_12h       0.016595  0.005605 -0.044099  0.001852   -0.016588
# noise_total_LDEN_55   -0.033650  0.000627 -0.007943 -0.082980    0.071444
# µgm3                  -0.041153  0.009391  0.045136 -0.009966    0.086523
# start_year             0.061721  0.071931 -0.064639  0.074608   -0.054866
# Totaltime             -0.006990  0.008804 -0.006089  0.064736   -0.023081
# age_yrs                0.042340  0.123950  0.003921 -0.004096    0.036598
# yearbirth             -0.042340 -0.123950 -0.003921  0.004096   -0.036598
#
#                       occurrence_stroop  ...  precip_12h_binary  \
# date_all                       0.206963  ...           0.026134
# year                           0.012571  ...          -0.009644
# day                            0.170914  ...           0.072477
# occurrence_mental              0.978449  ...          -0.119389
# bienestar                      0.025074  ...           0.015061
# energia                        0.051859  ...          -0.010369
# estres                        -0.116117  ...          -0.044012
# sueno                          0.029329  ...           0.020007
# horasfuera                    -0.055821  ...          -0.009988
# occurrence_stroop              1.000000  ...          -0.118501
# mean_incongruent              -0.265272  ...           0.000450
# correct                        0.058597  ...          -0.013892
# response_duration_ms          -0.265272  ...           0.000450
# performance                    0.275947  ...          -0.016443
# mean_congruent                -0.264169  ...           0.001382
# inhib_control                 -0.020516  ...          -0.001275
# z_performance                 -0.015624  ...           0.014796
# z_mean_incongruent             0.021134  ...          -0.016900
# z_inhib_control                0.006772  ...           0.009009
# no2bcn_24h                     0.168598  ...          -0.165457
# no2bcn_12h                     0.142572  ...          -0.109216
# no2gps_24h                     0.172517  ...          -0.171823
# no2gps_12h                     0.155258  ...          -0.141077
# no2bcn_12h_x30                 0.142572  ...          -0.109216
# no2bcn_24h_x30                 0.168598  ...          -0.165457
# no2gps_12h_x30                 0.172517  ...          -0.171823
# no2gps_24h_x30                 0.172517  ...          -0.171823
# min_gps                        0.047943  ...           0.014245
# hour_gps                       0.047943  ...           0.014245
# pm25bcn                        0.221804  ...          -0.192726
# BCμg                           0.182889  ...          -0.097486
# sec_noise55_day                0.047214  ...          -0.004896
# sec_noise65_day               -0.036967  ...           0.025491
# sec_greenblue_day              0.011218  ...          -0.003059
# hours_noise_55_day             0.047214  ...          -0.004896
# hours_noise_65_day            -0.036967  ...           0.025491
# hours_greenblue_day            0.011218  ...          -0.003059
# tmean_24h                     -0.195825  ...           0.072153
# tmean_12h                     -0.156992  ...          -0.055574
# humi_24h                      -0.045083  ...           0.485333
# humi_12h                      -0.039078  ...           0.514877
# pressure_24h                   0.217083  ...          -0.226848
# pressure_12h                   0.219457  ...          -0.265347
# precip_24h                    -0.119634  ...           0.628795
# precip_12h                    -0.066071  ...           0.525302
# precip_12h_binary             -0.118501  ...           1.000000
# precip_24h_binary             -0.173475  ...           0.725645
# maxwindspeed_24h              -0.107046  ...           0.538758
# maxwindspeed_12h              -0.090468  ...           0.592710
# noise_total_LDEN_55            0.035532  ...          -0.012580
# µgm3                          -0.029458  ...           0.019378
# start_year                     0.012571  ...          -0.009644
# Totaltime                      0.021895  ...           0.011703
# age_yrs                        0.051417  ...          -0.028137
# yearbirth                     -0.051417  ...           0.028137
#
#                       precip_24h_binary  maxwindspeed_24h  maxwindspeed_12h  \
# date_all                       0.041038         -0.114160         -0.091535
# year                           0.025409         -0.055029         -0.040256
# day                            0.013391          0.000333          0.036089
# occurrence_mental             -0.173590         -0.112342         -0.094289
# bienestar                     -0.003791          0.036290          0.016595
# energia                       -0.007857          0.024149          0.005605
# estres                        -0.018109         -0.062502         -0.044099
# sueno                          0.020275          0.022286          0.001852
# horasfuera                    -0.001775         -0.024327         -0.016588
# occurrence_stroop             -0.173475         -0.107046         -0.090468
# mean_incongruent               0.011799         -0.003273         -0.005506
# correct                       -0.015030         -0.001895         -0.008845
# response_duration_ms           0.011799         -0.003273         -0.005506
# performance                   -0.035033         -0.009602         -0.001048
# mean_congruent                 0.016977          0.002954          0.009918
# inhib_control                 -0.006423         -0.008973         -0.022037
# z_performance                  0.019659          0.028109          0.028137
# z_mean_incongruent            -0.025358         -0.031369         -0.028942
# z_inhib_control                0.005208         -0.000209         -0.018464
# no2bcn_24h                    -0.164320         -0.218960         -0.133486
# no2bcn_12h                    -0.108660         -0.170959         -0.113202
# no2gps_24h                    -0.134434         -0.218855         -0.156874
# no2gps_12h                    -0.102364         -0.171203         -0.143511
# no2bcn_12h_x30                -0.108660         -0.170959         -0.113202
# no2bcn_24h_x30                -0.164320         -0.218960         -0.133486
# no2gps_12h_x30                -0.134434         -0.218855         -0.156874
# no2gps_24h_x30                -0.134434         -0.218855         -0.156874
# min_gps                        0.029869          0.026949          0.013857
# hour_gps                       0.029869          0.026949          0.013857
# pm25bcn                       -0.302073         -0.287074         -0.184600
# BCμg                          -0.179921         -0.140095         -0.063861
# sec_noise55_day               -0.005536          0.013172         -0.006973
# sec_noise65_day                0.021041          0.028432          0.011761
# sec_greenblue_day             -0.012837         -0.023663         -0.014650
# hours_noise_55_day            -0.005536          0.013172         -0.006973
# hours_noise_65_day             0.021041          0.028432          0.011761
# hours_greenblue_day           -0.012837         -0.023663         -0.014650
# tmean_24h                      0.036582          0.115584          0.167877
# tmean_12h                     -0.072619          0.012389          0.053976
# humi_24h                       0.477276          0.385180          0.346835
# humi_12h                       0.438295          0.363161          0.394484
# pressure_24h                  -0.216056         -0.005517         -0.005183
# pressure_12h                  -0.249139         -0.027899         -0.025016
# precip_24h                     0.582471          0.808393          0.635381
# precip_12h                     0.381182          0.763442          0.952136
# precip_12h_binary              0.725645          0.538758          0.592710
# precip_24h_binary              1.000000          0.593997          0.430096
# maxwindspeed_24h               0.593997          1.000000          0.801333
# maxwindspeed_12h               0.430096          0.801333          1.000000
# noise_total_LDEN_55           -0.027666         -0.030066         -0.021183
# µgm3                           0.025113          0.038740          0.024353
# start_year                     0.025409         -0.055029         -0.040256
# Totaltime                      0.028192          0.009652          0.010517
# age_yrs                        0.006666         -0.004065         -0.003377
# yearbirth                     -0.006666          0.004065          0.003377
#
#                       noise_total_LDEN_55      µgm3  start_year  Totaltime  \
# date_all                        -0.001121 -0.080063    0.665819   0.031419
# year                            -0.010552 -0.051819    1.000000  -0.005073
# day                             -0.018343 -0.020276   -0.043715   0.042935
# occurrence_mental                0.053280 -0.038903    0.015168   0.010184
# bienestar                       -0.033650 -0.041153    0.061721  -0.006990
# energia                          0.000627  0.009391    0.071931   0.008804
# estres                          -0.007943  0.045136   -0.064639  -0.006089
# sueno                           -0.082980 -0.009966    0.074608   0.064736
# horasfuera                       0.071444  0.086523   -0.054866  -0.023081
# occurrence_stroop                0.035532 -0.029458    0.012571   0.021895
# mean_incongruent                 0.013972  0.102116    0.203487  -0.008753
# correct                         -0.016527  0.035337   -0.021971   0.010808
# response_duration_ms             0.013972  0.102116    0.203487  -0.008753
# performance                     -0.041303 -0.129987   -0.211453   0.001165
# mean_congruent                   0.005172  0.097323    0.159326  -0.026989
# inhib_control                    0.013348  0.014027    0.076516   0.024962
# z_performance                   -0.055455 -0.127945   -0.221963  -0.007046
# z_mean_incongruent               0.032595  0.102859    0.224699   0.000517
# z_inhib_control                  0.005698  0.025245    0.067547   0.015990
# no2bcn_24h                       0.038411 -0.001748   -0.021137  -0.060850
# no2bcn_12h                       0.040962  0.000389   -0.021757  -0.063868
# no2gps_24h                       0.042748  0.012867   -0.014210  -0.043563
# no2gps_12h                       0.038977  0.025240   -0.049773  -0.060814
# no2bcn_12h_x30                   0.040962  0.000389   -0.021757  -0.063868
# no2bcn_24h_x30                   0.038411 -0.001748   -0.021137  -0.060850
# no2gps_12h_x30                   0.042748  0.012867   -0.014210  -0.043563
# no2gps_24h_x30                   0.042748  0.012867   -0.014210  -0.043563
# min_gps                          0.127588  0.043628    0.019462   0.010516
# hour_gps                         0.127588  0.043628    0.019462   0.010516
# pm25bcn                          0.034461  0.007738    0.098803  -0.080280
# BCμg                             0.047413  0.014087   -0.029657  -0.070315
# sec_noise55_day                  0.185050  0.059401   -0.041043   0.059287
# sec_noise65_day                  0.079170  0.112833   -0.059778  -0.007538
# sec_greenblue_day                0.128564 -0.041622    0.053121  -0.006006
# hours_noise_55_day               0.185050  0.059401   -0.041043   0.059287
# hours_noise_65_day               0.079170  0.112833   -0.059778  -0.007538
# hours_greenblue_day              0.128564 -0.041622    0.053121  -0.006006
# tmean_24h                        0.016287  0.087325   -0.204212  -0.050125
# tmean_12h                        0.014456  0.083746   -0.210934  -0.048437
# humi_24h                         0.012071  0.042580    0.064038  -0.040794
# humi_12h                         0.014821  0.031412    0.070522  -0.039513
# pressure_24h                     0.005866  0.057937   -0.028672  -0.054809
# pressure_12h                     0.001914  0.051506   -0.023083  -0.049859
# precip_24h                      -0.038224  0.020961   -0.052179   0.000681
# precip_12h                      -0.020017  0.022475   -0.023942   0.014700
# precip_12h_binary               -0.012580  0.019378   -0.009644   0.011703
# precip_24h_binary               -0.027666  0.025113    0.025409   0.028192
# maxwindspeed_24h                -0.030066  0.038740   -0.055029   0.009652
# maxwindspeed_12h                -0.021183  0.024353   -0.040256   0.010517
# noise_total_LDEN_55              1.000000  0.100999   -0.010552   0.056248
# µgm3                             0.100999  1.000000   -0.051819  -0.043273
# start_year                      -0.010552 -0.051819    1.000000  -0.005073
# Totaltime                        0.056248 -0.043273   -0.005073   1.000000
# age_yrs                          0.064553  0.084805    0.243454   0.027152
# yearbirth                       -0.064553 -0.084805   -0.243454  -0.027152
#
#                        age_yrs  yearbirth
# date_all              0.078506  -0.078506
# year                  0.243454  -0.243454
# day                   0.027752  -0.027752
# occurrence_mental     0.068618  -0.068618
# bienestar             0.042340  -0.042340
# energia               0.123950  -0.123950
# estres                0.003921  -0.003921
# sueno                -0.004096   0.004096
# horasfuera            0.036598  -0.036598
# occurrence_stroop     0.051417  -0.051417
# mean_incongruent      0.417635  -0.417635
# correct               0.005652  -0.005652
# response_duration_ms  0.417635  -0.417635
# performance          -0.435234   0.435234
# mean_congruent        0.414446  -0.414446
# inhib_control         0.034338  -0.034338
# z_performance        -0.471461   0.471461
# z_mean_incongruent    0.465082  -0.465082
# z_inhib_control       0.016677  -0.016677
# no2bcn_24h           -0.012508   0.012508
# no2bcn_12h           -0.013082   0.013082
# no2gps_24h           -0.020701   0.020701
# no2gps_12h           -0.022798   0.022798
# no2bcn_12h_x30       -0.013082   0.013082
# no2bcn_24h_x30       -0.012508   0.012508
# no2gps_12h_x30       -0.020701   0.020701
# no2gps_24h_x30       -0.020701   0.020701
# min_gps              -0.036059   0.036059
# hour_gps             -0.036059   0.036059
# pm25bcn               0.063013  -0.063013
# BCμg                  0.004511  -0.004511
# sec_noise55_day      -0.117228   0.117228
# sec_noise65_day      -0.067399   0.067399
# sec_greenblue_day    -0.051590   0.051590
# hours_noise_55_day   -0.117228   0.117228
# hours_noise_65_day   -0.067399   0.067399
# hours_greenblue_day  -0.051590   0.051590
# tmean_24h             0.034776  -0.034776
# tmean_12h             0.038813  -0.038813
# humi_24h             -0.007757   0.007757
# humi_12h             -0.013394   0.013394
# pressure_24h          0.149048  -0.149048
# pressure_12h          0.155002  -0.155002
# precip_24h           -0.042390   0.042390
# precip_12h            0.007647  -0.007647
# precip_12h_binary    -0.028137   0.028137
# precip_24h_binary     0.006666  -0.006666
# maxwindspeed_24h     -0.004065   0.004065
# maxwindspeed_12h     -0.003377   0.003377
# noise_total_LDEN_55   0.064553  -0.064553
# µgm3                  0.084805  -0.084805
# start_year            0.243454  -0.243454
# Totaltime             0.027152  -0.027152
# age_yrs               1.000000  -1.000000
# yearbirth            -1.000000   1.000000
#
# [55 rows x 55 columns]

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3188 entries, 3 to 3310
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1594 non-null   float64
#  1   year                  1594 non-null   float64
#  2   day                   1594 non-null   float64
#  3   occurrence_mental     1594 non-null   float64
#  4   bienestar             1594 non-null   float64
#  5   energia               1594 non-null   float64
#  6   estres                1594 non-null   float64
#  7   sueno                 1594 non-null   float64
#  8   horasfuera            1594 non-null   float64
#  9   occurrence_stroop     1594 non-null   float64
#  10  mean_incongruent      1594 non-null   float64
#  11  correct               1594 non-null   float64
#  12  response_duration_ms  1594 non-null   float64
#  13  performance           1594 non-null   float64
#  14  mean_congruent        1594 non-null   float64
#  15  inhib_control         1594 non-null   float64
#  16  z_performance         1594 non-null   float64
#  17  z_mean_incongruent    1594 non-null   float64
#  18  z_inhib_control       1594 non-null   float64
#  19  no2bcn_24h            1594 non-null   float64
#  20  no2bcn_12h            1594 non-null   float64
#  21  no2gps_24h            1594 non-null   float64
#  22  no2gps_12h            1594 non-null   float64
#  23  no2bcn_12h_x30        1594 non-null   float64
#  24  no2bcn_24h_x30        1594 non-null   float64
#  25  no2gps_12h_x30        1594 non-null   float64
#  26  no2gps_24h_x30        1594 non-null   float64
#  27  min_gps               1594 non-null   float64
#  28  hour_gps              1594 non-null   float64
#  29  pm25bcn               1594 non-null   float64
#  30  BCμg                  1594 non-null   float64
#  31  sec_noise55_day       1594 non-null   float64
#  32  sec_noise65_day       1594 non-null   float64
#  33  sec_greenblue_day     1594 non-null   float64
#  34  hours_noise_55_day    1594 non-null   float64
#  35  hours_noise_65_day    1594 non-null   float64
#  36  hours_greenblue_day   1594 non-null   float64
#  37  tmean_24h             1594 non-null   float64
#  38  tmean_12h             1594 non-null   float64
#  39  humi_24h              1594 non-null   float64
#  40  humi_12h              1594 non-null   float64
#  41  pressure_24h          1594 non-null   float64
#  42  pressure_12h          1594 non-null   float64
#  43  precip_24h            1594 non-null   float64
#  44  precip_12h            1594 non-null   float64
#  45  precip_12h_binary     1594 non-null   float64
#  46  precip_24h_binary     1594 non-null   float64
#  47  maxwindspeed_24h      1594 non-null   float64
#  48  maxwindspeed_12h      1594 non-null   float64
#  49  noise_total_LDEN_55   1594 non-null   float64
#  50  µgm3                  1594 non-null   float64
#  51  start_year            1594 non-null   float64
#  52  Totaltime             1594 non-null   float64
#  53  age_yrs               1594 non-null   float64
#  54  yearbirth             1594 non-null   float64
# dtypes: float64(55)
# memory usage: 1.4 MB

# %%
numerical_df=numerical_df.dropna()
columns=["sueno","estres","energia","bienestar"]
numerical_df.boxplot(column=columns)
numerical_df=remove_outliers_iqr(numerical_df,columns)

# %%
scaler=StandardScaler()


#clustering_df=.drop("bienestar",axis=1)
#scaler_target=StandardScaler()
"""
numerical_df["bienestar"]=cut_into_bins(numerical_df["bienestar"],3)
numerical_df["energia"]=cut_into_bins(numerical_df["energia"],3)
numerical_df["estres"]=cut_into_bins(numerical_df["estres"],3)
numerical_df["sueno"]=cut_into_bins(numerical_df["sueno"],3)
"""
scaler1=StandardScaler()
scaler_bienestar=StandardScaler()
#energia
scaler_energia=StandardScaler()
#estres
scaler_estres=StandardScaler()
#sueno
scaler_sueno=StandardScaler()
#Scaled=pd.DataFrame(scaler.fit_transform(clustering_df.drop("bienestar",axis=1)),columns=clustering_df.drop("bienestar",axis=1).columns,index=clustering_df.index)
#Scaled=pd.concat([Scaled,pd.DataFrame(scaler_target.fit_transform(clustering_df[["bienestar"]]),columns=["bienestar"])],axis=1)
#X_scaled["bienestar"]=X_scaled["bienestar"]*10
Scaled_x=numerical_df.drop(["bienestar","energia","estres","sueno"],axis=1)
Scaled_x=pd.DataFrame(scaler1.fit_transform(Scaled_x),columns=Scaled_x.columns)
Scaled_y_bienestar=pd.DataFrame(scaler_bienestar.fit_transform(numerical_df[["bienestar"]]),columns=["bienestar"])
Scaled_y_sueno=pd.DataFrame(scaler_sueno.fit_transform(numerical_df[["sueno"]]),columns=["sueno"])
Scaled_y_energia=pd.DataFrame(scaler_energia.fit_transform(numerical_df[["energia"]]),columns=["energia"])
Scaled_y_estres=pd.DataFrame(scaler_estres.fit_transform(numerical_df[["estres"]]),columns=["estres"])
Scaled=pd.concat([Scaled_x,Scaled_y_bienestar,
                 Scaled_y_sueno,Scaled_y_energia,Scaled_y_estres],axis=1)

# %%
Scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 55 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1501 non-null   float64
#  1   year                  1501 non-null   float64
#  2   day                   1501 non-null   float64
#  3   occurrence_mental     1501 non-null   float64
#  4   horasfuera            1501 non-null   float64
#  5   occurrence_stroop     1501 non-null   float64
#  6   mean_incongruent      1501 non-null   float64
#  7   correct               1501 non-null   float64
#  8   response_duration_ms  1501 non-null   float64
#  9   performance           1501 non-null   float64
#  10  mean_congruent        1501 non-null   float64
#  11  inhib_control         1501 non-null   float64
#  12  z_performance         1501 non-null   float64
#  13  z_mean_incongruent    1501 non-null   float64
#  14  z_inhib_control       1501 non-null   float64
#  15  no2bcn_24h            1501 non-null   float64
#  16  no2bcn_12h            1501 non-null   float64
#  17  no2gps_24h            1501 non-null   float64
#  18  no2gps_12h            1501 non-null   float64
#  19  no2bcn_12h_x30        1501 non-null   float64
#  20  no2bcn_24h_x30        1501 non-null   float64
#  21  no2gps_12h_x30        1501 non-null   float64
#  22  no2gps_24h_x30        1501 non-null   float64
#  23  min_gps               1501 non-null   float64
#  24  hour_gps              1501 non-null   float64
#  25  pm25bcn               1501 non-null   float64
#  26  BCμg                  1501 non-null   float64
#  27  sec_noise55_day       1501 non-null   float64
#  28  sec_noise65_day       1501 non-null   float64
#  29  sec_greenblue_day     1501 non-null   float64
#  30  hours_noise_55_day    1501 non-null   float64
#  31  hours_noise_65_day    1501 non-null   float64
#  32  hours_greenblue_day   1501 non-null   float64
#  33  tmean_24h             1501 non-null   float64
#  34  tmean_12h             1501 non-null   float64
#  35  humi_24h              1501 non-null   float64
#  36  humi_12h              1501 non-null   float64
#  37  pressure_24h          1501 non-null   float64
#  38  pressure_12h          1501 non-null   float64
#  39  precip_24h            1501 non-null   float64
#  40  precip_12h            1501 non-null   float64
#  41  precip_12h_binary     1501 non-null   float64
#  42  precip_24h_binary     1501 non-null   float64
#  43  maxwindspeed_24h      1501 non-null   float64
#  44  maxwindspeed_12h      1501 non-null   float64
#  45  noise_total_LDEN_55   1501 non-null   float64
#  46  µgm3                  1501 non-null   float64
#  47  start_year            1501 non-null   float64
#  48  Totaltime             1501 non-null   float64
#  49  age_yrs               1501 non-null   float64
#  50  yearbirth             1501 non-null   float64
#  51  bienestar             1501 non-null   float64
#  52  sueno                 1501 non-null   float64
#  53  energia               1501 non-null   float64
#  54  estres                1501 non-null   float64
# dtypes: float64(55)
# memory usage: 645.1 KB

# %%
silhouette_scores = []
k_values = range(2, 11) # Start from 2, as a silhouette score is not defined for k=1

for k in k_values:
    # Apply K-Means
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(Scaled)

    # Get the cluster labels for each data point
    labels = kmeans.labels_

    # Calculate the silhouette score
    score = silhouette_score(Scaled, labels)
    silhouette_scores.append(score)

    print(f"For k={k}, the silhouette score is: {score:.4f}")
# Out:
# For k=2, the silhouette score is: 0.1119
# For k=3, the silhouette score is: 0.1157
# For k=4, the silhouette score is: 0.1133
# For k=5, the silhouette score is: 0.1114
# For k=6, the silhouette score is: 0.1054
# For k=7, the silhouette score is: 0.1115
# For k=8, the silhouette score is: 0.0933
# For k=9, the silhouette score is: 0.0957
# For k=10, the silhouette score is: 0.0894

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, silhouette_scores, marker='o', linestyle='--')
plt.title('Silhouette Scores for Different Number of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Average Silhouette Score')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# Find the optimal k value
optimal_k_index = np.argmax(silhouette_scores)
optimal_k = k_values[optimal_k_index]

print(f"\n The optimal number of clusters (k) is approximately: {optimal_k}")
# Out:
#  The optimal number of clusters (k) is approximately: 3

# %%
Scaled_clean = Scaled.copy()
estres=Scaled_clean[["estres"]]
energia=Scaled_clean[["energia"]]
sueno=Scaled_clean[["sueno"]]
bienestar=Scaled_clean[["bienestar"]]

# %%
pca = PCA()
pca.fit(Scaled_clean)


explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

# Step 5: Plot the explained variance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--')
plt.title('Explained Variance Plot')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.axhline(y=0.95, color='r', linestyle='-', label='95% Explained Variance Threshold')
plt.legend(loc='lower right')
plt.show()

# %%
Scaled_clean.drop(["bienestar","energia","estres","sueno"],axis=1,inplace=True)

# %%
X=Scaled_clean
Y=pd.DataFrame(bienestar,columns=["bienestar"])

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    Y, 
    test_size=0.2, 
    random_state=42
)

# %%
model = LinearRegression()

# Train model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.8015
# R-squared (R2): -0.0360

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 1.07
# Root Mean Squared Error: 1.03

# %%
# Initialize the XGBoost Regressor model
xgb_regressor = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42
)


# Train the model on the training data
xgb_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Make predictions on the test set
y_pred = xgb_regressor.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 0.79
# Root Mean Squared Error: 0.89

# %%
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.6904
# R-squared (R2): 0.2360

# %%
print(len(X_train.columns))
# Out:
# 51

# %%
def f(column_to_predict):
    global estres,sueno,energia,bienestar,X
    to_predict={"estres":estres,"sueno":sueno,"energia":energia,"bienestar":bienestar}
    Y=pd.DataFrame(to_predict[column_to_predict],columns=[column_to_predict])
    Y.info()
    Y[column_to_predict]=cut_into_bins(Y[column_to_predict],2,bin_vertices=[Y[column_to_predict].min(),Y[column_to_predict].quantile(0.5),Y[column_to_predict].max()]).astype("int")
    
    #Y.info()
    
    #Y["estres"]=cut_into_bins/(Y["estres"],3).astype("int").astype("category")
    
    X_train, X_test, y_train, y_test = train_test_split(
        X, 
        Y, 
        test_size=0.2, 
        random_state=42
    )
    
    weights=[1,1]
    X_train_resampled, y_train_resampled = oversampling(X_train,y_train,2,weights)
    #X_train_resampled,y_train_resampled=X_train,y_train
    model = xgb.XGBClassifier(
        n_estimators=100,     # Number of boosting rounds (trees)
        learning_rate=0.1,    # Step size
        max_depth=10,          # Depth of trees
        use_label_encoder=False, # Avoids warning
        eval_metric="mlogloss",  # Multi-class log loss
        random_state=42,
        enable_categorical=True,
        scale_pos_weight=4.5538
    )
    model.fit(X_train_resampled, y_train_resampled)
    
    
    together=pd.concat([X_test,y_test],axis=1)
    min_length=min(len(y_test[y_test[column_to_predict]==0]),len(y_test[y_test[column_to_predict]==1]))
    X1_sample = together[together[column_to_predict]==1]
    X0_sample=together[together[column_to_predict]==0].sample(n=min_length, random_state=42,replace=False)
    X_sample=pd.concat([X1_sample,X0_sample]).sample(n=min_length, random_state=42,replace=False)
    Y_sample=X_sample[column_to_predict]
    X_sample.drop(columns=[column_to_predict],axis=1,inplace=True)
    y_pred = model.predict(X_sample)
    
    
    # y_true: true binary labels (0 or 1)
    # y_scores: model's predicted probabilities or decision function values
    y_scores = model.predict_proba(X_sample)[:, 1]
    precision, recall, thresholds = precision_recall_curve(Y_sample, y_scores)
    
    # Method 1: Standard AUC of the PR curve
    auc_pr = auc(recall, precision)
    
    # Method 2: Average Precision (AP), more common in ML papers
    ap_score = average_precision_score(Y_sample, y_pred)
    
    print("AUC-PR:", auc_pr)
    print("Average Precision (AP):", ap_score)
    print("Accuracy:", accuracy_score(Y_sample, y_pred))
    print("\nClassification Report:\n", classification_report(Y_sample, y_pred))
    
    
    cm = confusion_matrix(Y_sample, y_pred)
    
    # Display
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
    disp.plot(cmap="Blues", values_format='d')
    plt.show()
    cm = confusion_matrix(Y_sample, y_pred)
    return model

# %%
model1=f("sueno")
xgb.plot_importance(model1, importance_type='gain')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sueno   1501 non-null   float64
# dtypes: float64(1)
# memory usage: 11.9 KB
# [np.float64(-2.3716992155418026), np.float64(-0.353603681228738), np.float64(1.6644918530843262)] duhifuhiufheufhu
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 538 to 1126
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1200 non-null   float64
#  1   year                  1200 non-null   float64
#  2   day                   1200 non-null   float64
#  3   occurrence_mental     1200 non-null   float64
#  4   horasfuera            1200 non-null   float64
#  5   occurrence_stroop     1200 non-null   float64
#  6   mean_incongruent      1200 non-null   float64
#  7   correct               1200 non-null   float64
#  8   response_duration_ms  1200 non-null   float64
#  9   performance           1200 non-null   float64
#  10  mean_congruent        1200 non-null   float64
#  11  inhib_control         1200 non-null   float64
#  12  z_performance         1200 non-null   float64
#  13  z_mean_incongruent    1200 non-null   float64
#  14  z_inhib_control       1200 non-null   float64
#  15  no2bcn_24h            1200 non-null   float64
#  16  no2bcn_12h            1200 non-null   float64
#  17  no2gps_24h            1200 non-null   float64
#  18  no2gps_12h            1200 non-null   float64
#  19  no2bcn_12h_x30        1200 non-null   float64
#  20  no2bcn_24h_x30        1200 non-null   float64
#  21  no2gps_12h_x30        1200 non-null   float64
#  22  no2gps_24h_x30        1200 non-null   float64
#  23  min_gps               1200 non-null   float64
#  24  hour_gps              1200 non-null   float64
#  25  pm25bcn               1200 non-null   float64
#  26  BCμg                  1200 non-null   float64
#  27  sec_noise55_day       1200 non-null   float64
#  28  sec_noise65_day       1200 non-null   float64
#  29  sec_greenblue_day     1200 non-null   float64
#  30  hours_noise_55_day    1200 non-null   float64
#  31  hours_noise_65_day    1200 non-null   float64
#  32  hours_greenblue_day   1200 non-null   float64
#  33  tmean_24h             1200 non-null   float64
#  34  tmean_12h             1200 non-null   float64
#  35  humi_24h              1200 non-null   float64
#  36  humi_12h              1200 non-null   float64
#  37  pressure_24h          1200 non-null   float64
#  38  pressure_12h          1200 non-null   float64
#  39  precip_24h            1200 non-null   float64
#  40  precip_12h            1200 non-null   float64
#  41  precip_12h_binary     1200 non-null   float64
#  42  precip_24h_binary     1200 non-null   float64
#  43  maxwindspeed_24h      1200 non-null   float64
#  44  maxwindspeed_12h      1200 non-null   float64
#  45  noise_total_LDEN_55   1200 non-null   float64
#  46  µgm3                  1200 non-null   float64
#  47  start_year            1200 non-null   float64
#  48  Totaltime             1200 non-null   float64
#  49  age_yrs               1200 non-null   float64
#  50  yearbirth             1200 non-null   float64
#  51  sueno                 1200 non-null   int64
# dtypes: float64(51), int64(1)
# memory usage: 496.9 KB
# C:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:10] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# AUC-PR: 0.6159392242662396
# Average Precision (AP): 0.5830895935960592
# Accuracy: 0.6190476190476191
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.66      0.63        62
#            1       0.64      0.58      0.61        64
#
#     accuracy                           0.62       126
#    macro avg       0.62      0.62      0.62       126
# weighted avg       0.62      0.62      0.62       126

# %%
model2=f("estres")
xgb.plot_importance(model2, importance_type='gain')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   estres  1501 non-null   float64
# dtypes: float64(1)
# memory usage: 11.9 KB
# [np.float64(-1.6494614131029), np.float64(0.3663679152373156), np.float64(2.3821972435775316)] duhifuhiufheufhu
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 538 to 1126
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1200 non-null   float64
#  1   year                  1200 non-null   float64
#  2   day                   1200 non-null   float64
#  3   occurrence_mental     1200 non-null   float64
#  4   horasfuera            1200 non-null   float64
#  5   occurrence_stroop     1200 non-null   float64
#  6   mean_incongruent      1200 non-null   float64
#  7   correct               1200 non-null   float64
#  8   response_duration_ms  1200 non-null   float64
#  9   performance           1200 non-null   float64
#  10  mean_congruent        1200 non-null   float64
#  11  inhib_control         1200 non-null   float64
#  12  z_performance         1200 non-null   float64
#  13  z_mean_incongruent    1200 non-null   float64
#  14  z_inhib_control       1200 non-null   float64
#  15  no2bcn_24h            1200 non-null   float64
#  16  no2bcn_12h            1200 non-null   float64
#  17  no2gps_24h            1200 non-null   float64
#  18  no2gps_12h            1200 non-null   float64
#  19  no2bcn_12h_x30        1200 non-null   float64
#  20  no2bcn_24h_x30        1200 non-null   float64
#  21  no2gps_12h_x30        1200 non-null   float64
#  22  no2gps_24h_x30        1200 non-null   float64
#  23  min_gps               1200 non-null   float64
#  24  hour_gps              1200 non-null   float64
#  25  pm25bcn               1200 non-null   float64
#  26  BCμg                  1200 non-null   float64
#  27  sec_noise55_day       1200 non-null   float64
#  28  sec_noise65_day       1200 non-null   float64
#  29  sec_greenblue_day     1200 non-null   float64
#  30  hours_noise_55_day    1200 non-null   float64
#  31  hours_noise_65_day    1200 non-null   float64
#  32  hours_greenblue_day   1200 non-null   float64
#  33  tmean_24h             1200 non-null   float64
#  34  tmean_12h             1200 non-null   float64
#  35  humi_24h              1200 non-null   float64
#  36  humi_12h              1200 non-null   float64
#  37  pressure_24h          1200 non-null   float64
#  38  pressure_12h          1200 non-null   float64
#  39  precip_24h            1200 non-null   float64
#  40  precip_12h            1200 non-null   float64
#  41  precip_12h_binary     1200 non-null   float64
#  42  precip_24h_binary     1200 non-null   float64
#  43  maxwindspeed_24h      1200 non-null   float64
#  44  maxwindspeed_12h      1200 non-null   float64
#  45  noise_total_LDEN_55   1200 non-null   float64
#  46  µgm3                  1200 non-null   float64
#  47  start_year            1200 non-null   float64
#  48  Totaltime             1200 non-null   float64
#  49  age_yrs               1200 non-null   float64
#  50  yearbirth             1200 non-null   float64
#  51  estres                1200 non-null   int64
# dtypes: float64(51), int64(1)
# memory usage: 496.9 KB
# C:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# AUC-PR: 0.7497149200652866
# Average Precision (AP): 0.6351243148127049
# Accuracy: 0.6870229007633588
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.64      0.67        64
#            1       0.68      0.73      0.71        67
#
#     accuracy                           0.69       131
#    macro avg       0.69      0.69      0.69       131
# weighted avg       0.69      0.69      0.69       131

# %%
model3=f("energia")
xgb.plot_importance(model3, importance_type='gain')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   energia  1501 non-null   float64
# dtypes: float64(1)
# memory usage: 11.9 KB
# [np.float64(-2.646131598874094), np.float64(-0.4140422676786777), np.float64(1.8180470635167387)] duhifuhiufheufhu
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 538 to 1126
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1200 non-null   float64
#  1   year                  1200 non-null   float64
#  2   day                   1200 non-null   float64
#  3   occurrence_mental     1200 non-null   float64
#  4   horasfuera            1200 non-null   float64
#  5   occurrence_stroop     1200 non-null   float64
#  6   mean_incongruent      1200 non-null   float64
#  7   correct               1200 non-null   float64
#  8   response_duration_ms  1200 non-null   float64
#  9   performance           1200 non-null   float64
#  10  mean_congruent        1200 non-null   float64
#  11  inhib_control         1200 non-null   float64
#  12  z_performance         1200 non-null   float64
#  13  z_mean_incongruent    1200 non-null   float64
#  14  z_inhib_control       1200 non-null   float64
#  15  no2bcn_24h            1200 non-null   float64
#  16  no2bcn_12h            1200 non-null   float64
#  17  no2gps_24h            1200 non-null   float64
#  18  no2gps_12h            1200 non-null   float64
#  19  no2bcn_12h_x30        1200 non-null   float64
#  20  no2bcn_24h_x30        1200 non-null   float64
#  21  no2gps_12h_x30        1200 non-null   float64
#  22  no2gps_24h_x30        1200 non-null   float64
#  23  min_gps               1200 non-null   float64
#  24  hour_gps              1200 non-null   float64
#  25  pm25bcn               1200 non-null   float64
#  26  BCμg                  1200 non-null   float64
#  27  sec_noise55_day       1200 non-null   float64
#  28  sec_noise65_day       1200 non-null   float64
#  29  sec_greenblue_day     1200 non-null   float64
#  30  hours_noise_55_day    1200 non-null   float64
#  31  hours_noise_65_day    1200 non-null   float64
#  32  hours_greenblue_day   1200 non-null   float64
#  33  tmean_24h             1200 non-null   float64
#  34  tmean_12h             1200 non-null   float64
#  35  humi_24h              1200 non-null   float64
#  36  humi_12h              1200 non-null   float64
#  37  pressure_24h          1200 non-null   float64
#  38  pressure_12h          1200 non-null   float64
#  39  precip_24h            1200 non-null   float64
#  40  precip_12h            1200 non-null   float64
#  41  precip_12h_binary     1200 non-null   float64
#  42  precip_24h_binary     1200 non-null   float64
#  43  maxwindspeed_24h      1200 non-null   float64
#  44  maxwindspeed_12h      1200 non-null   float64
#  45  noise_total_LDEN_55   1200 non-null   float64
#  46  µgm3                  1200 non-null   float64
#  47  start_year            1200 non-null   float64
#  48  Totaltime             1200 non-null   float64
#  49  age_yrs               1200 non-null   float64
#  50  yearbirth             1200 non-null   float64
#  51  energia               1200 non-null   int64
# dtypes: float64(51), int64(1)
# memory usage: 496.9 KB
# C:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# AUC-PR: 0.7121142872530873
# Average Precision (AP): 0.5855256701220635
# Accuracy: 0.6204379562043796
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.63      0.62        67
#            1       0.63      0.61      0.62        70
#
#     accuracy                           0.62       137
#    macro avg       0.62      0.62      0.62       137
# weighted avg       0.62      0.62      0.62       137

# %%
model4=f("bienestar")
xgb.plot_importance(model4, importance_type='gain')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1501 entries, 0 to 1500
# Data columns (total 1 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   bienestar  1501 non-null   float64
# dtypes: float64(1)
# memory usage: 11.9 KB
# [np.float64(-2.921089808374814), np.float64(-0.5934779005487738), np.float64(1.7341340072772669)] duhifuhiufheufhu
# <class 'pandas.core.frame.DataFrame'>
# Index: 1200 entries, 538 to 1126
# Data columns (total 52 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1200 non-null   float64
#  1   year                  1200 non-null   float64
#  2   day                   1200 non-null   float64
#  3   occurrence_mental     1200 non-null   float64
#  4   horasfuera            1200 non-null   float64
#  5   occurrence_stroop     1200 non-null   float64
#  6   mean_incongruent      1200 non-null   float64
#  7   correct               1200 non-null   float64
#  8   response_duration_ms  1200 non-null   float64
#  9   performance           1200 non-null   float64
#  10  mean_congruent        1200 non-null   float64
#  11  inhib_control         1200 non-null   float64
#  12  z_performance         1200 non-null   float64
#  13  z_mean_incongruent    1200 non-null   float64
#  14  z_inhib_control       1200 non-null   float64
#  15  no2bcn_24h            1200 non-null   float64
#  16  no2bcn_12h            1200 non-null   float64
#  17  no2gps_24h            1200 non-null   float64
#  18  no2gps_12h            1200 non-null   float64
#  19  no2bcn_12h_x30        1200 non-null   float64
#  20  no2bcn_24h_x30        1200 non-null   float64
#  21  no2gps_12h_x30        1200 non-null   float64
#  22  no2gps_24h_x30        1200 non-null   float64
#  23  min_gps               1200 non-null   float64
#  24  hour_gps              1200 non-null   float64
#  25  pm25bcn               1200 non-null   float64
#  26  BCμg                  1200 non-null   float64
#  27  sec_noise55_day       1200 non-null   float64
#  28  sec_noise65_day       1200 non-null   float64
#  29  sec_greenblue_day     1200 non-null   float64
#  30  hours_noise_55_day    1200 non-null   float64
#  31  hours_noise_65_day    1200 non-null   float64
#  32  hours_greenblue_day   1200 non-null   float64
#  33  tmean_24h             1200 non-null   float64
#  34  tmean_12h             1200 non-null   float64
#  35  humi_24h              1200 non-null   float64
#  36  humi_12h              1200 non-null   float64
#  37  pressure_24h          1200 non-null   float64
#  38  pressure_12h          1200 non-null   float64
#  39  precip_24h            1200 non-null   float64
#  40  precip_12h            1200 non-null   float64
#  41  precip_12h_binary     1200 non-null   float64
#  42  precip_24h_binary     1200 non-null   float64
#  43  maxwindspeed_24h      1200 non-null   float64
#  44  maxwindspeed_12h      1200 non-null   float64
#  45  noise_total_LDEN_55   1200 non-null   float64
#  46  µgm3                  1200 non-null   float64
#  47  start_year            1200 non-null   float64
#  48  Totaltime             1200 non-null   float64
#  49  age_yrs               1200 non-null   float64
#  50  yearbirth             1200 non-null   float64
#  51  bienestar             1200 non-null   int64
# dtypes: float64(51), int64(1)
# memory usage: 496.9 KB
# C:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [00:06:16] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# AUC-PR: 0.672876678927275
# Average Precision (AP): 0.6003195845400978
# Accuracy: 0.5645161290322581
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.79      0.62        28
#            1       0.68      0.38      0.49        34
#
#     accuracy                           0.56        62
#    macro avg       0.60      0.58      0.56        62
# weighted avg       0.61      0.56      0.55        62

# %%
explainer = shap.TreeExplainer(model1)
shap_values = explainer.shap_values(X_train)


shap.summary_plot(shap_values, X_train)

# %%
explainer = shap.TreeExplainer(model2)
shap_values = explainer.shap_values(X_train)


shap.summary_plot(shap_values, X_train)

# %%
explainer = shap.TreeExplainer(model3)
shap_values = explainer.shap_values(X_train)


shap.summary_plot(shap_values, X_train)

# %%
explainer = shap.TreeExplainer(model4)
shap_values = explainer.shap_values(X_train)


shap.summary_plot(shap_values, X_train)

# %%
bienestar

no2bcn inversely proportional
no2gps inversely proportional
sec_greenblue_day directly proportional
age inversely proportional
pressure directly proportional
# Out:
#   Cell In[48], line 3
#     no2bcn inversely proportional
#            ^
# SyntaxError: invalid syntax

# %%
energia

sec_greenblue_day directly proportional
no2gps inversely proportional
gender directly proportional

# %%
estres

no2bcn directly proportional
performance inversely proportional
pressure inversely proportional
Totak time inversely proportional
no2gps directly proportional

# %%
suena

no2_gps invversely proportional
horasfuera invversely proportional
Total time directly proportional
sec_noise55_day inversely proportional
