# %%
import pandas as pd
import seaborn as sns
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from sklearn.neighbors import NearestNeighbors
import numpy as np
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.linear_model import LinearRegression
import shap
from sklearn.metrics import mean_absolute_error, r2_score
from xgboost import plot_importance
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import accuracy_score, classification_report
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.utils import resample
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_classification
from imblearn.over_sampling import ADASYN
from sklearn.metrics import precision_recall_curve, auc, average_precision_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
df=pd.read_csv("air-pollution.csv",header=0)
df.drop(["start_hour","start_month","start_day","end_year","end_month","end_hour","end_day","month","dayoftheweek","hour"],axis=1,inplace=True)

# %%
def cut_into_bins(column,num,bin_vertices=None):
    #print(column.describe())
    maxx=column.max()
    minn=column.min()
    step=(maxx-minn)/num
    
    bins=[minn+(i*step) for i in range(num)]+[maxx]
    print(bins,"duhifuhiufheufhu")
    if bin_vertices!=None:
        bins=bin_vertices
    #bins=[0,3.333,6.666,10]
    #print(bins,"bruh")
    labels=list(range(0,num))
    #print(bins,max(column),min(column),step)
    return pd.cut(column,bins=bins,labels=labels,include_lowest=True)
def oversampling(X_train,Y_train,num_bins,weights):
    together=pd.concat([X_train,Y_train],axis=1)
    together.info()
    #print(X_train.info())
    #print(Y_train.info())
    class_column=Y_train.columns.tolist()[0]
    class1=together[together[class_column]==0]
    class2=together[together[class_column]==1]
    class3=together[together[class_column]==2]

    classes=[together[together[class_column]==i] for i in range(num_bins)]
    lengths=[len(classes[i]) for i in range(num_bins)]
    max_length=max(lengths)
    mindex=lengths.index(max_length)

    for i in range(num_bins):
        if i!=mindex:
            classes[i]=resample(classes[i],
                               replace=True,
                               n_samples=max_length*weights[i],
                               random_state=42)

    
   

    mainn= pd.concat(classes)
    return mainn.drop(class_column,axis=1),mainn[class_column]
def remove_outliers_iqr(df,columns):
    # For each numeric column
    for col in columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        if lower<0:
            lower=0
        upper = Q3 + 1.5 * IQR
        if upper>10:
            upper=10
        df = df[(df[col] >= lower) & (df[col] <= upper)]
    return df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 85 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   ID_Zenodo                        3348 non-null   int64
#  1   date_all                         3348 non-null   int64
#  2   year                             3348 non-null   int64
#  3   day                              3348 non-null   int64
#  4   mentalhealth_survey              3348 non-null   object
#  5   occurrence_mental                3280 non-null   float64
#  6   bienestar                        3273 non-null   float64
#  7   energia                          3207 non-null   float64
#  8   estres                           3173 non-null   float64
#  9   sueno                            3190 non-null   float64
#  10  horasfuera                       3231 non-null   float64
#  11  actividadfisica                  3232 non-null   object
#  12  ordenador                        3227 non-null   object
#  13  dieta                            3226 non-null   object
#  14  alcohol                          3222 non-null   object
#  15  drogas                           3227 non-null   object
#  16  bebida                           3225 non-null   object
#  17  enfermo                          3221 non-null   object
#  18  otrofactor                       3210 non-null   object
#  19  stroop_test                      3348 non-null   object
#  20  occurrence_stroop                3046 non-null   float64
#  21  mean_incongruent                 3046 non-null   float64
#  22  correct                          3046 non-null   float64
#  23  response_duration_ms             3046 non-null   float64
#  24  performance                      3046 non-null   float64
#  25  mean_congruent                   3046 non-null   float64
#  26  inhib_control                    3046 non-null   float64
#  27  z_performance                    3046 non-null   float64
#  28  z_mean_incongruent               3046 non-null   float64
#  29  z_inhib_control                  3046 non-null   float64
#  30  no2bcn_24h                       3348 non-null   float64
#  31  no2bcn_12h                       3348 non-null   float64
#  32  no2gps_24h                       3151 non-null   float64
#  33  no2gps_12h                       3146 non-null   float64
#  34  no2bcn_12h_x30                   3348 non-null   float64
#  35  no2bcn_24h_x30                   3348 non-null   float64
#  36  no2gps_12h_x30                   3151 non-null   float64
#  37  no2gps_24h_x30                   3151 non-null   float64
#  38  min_gps                          3242 non-null   float64
#  39  hour_gps                         3242 non-null   float64
#  40  pm25bcn                          3348 non-null   float64
#  41  BCμg                             3068 non-null   float64
#  42  sec_noise55_day                  2858 non-null   float64
#  43  sec_noise65_day                  2858 non-null   float64
#  44  sec_greenblue_day                2858 non-null   float64
#  45  hours_noise_55_day               2858 non-null   float64
#  46  hours_noise_65_day               2858 non-null   float64
#  47  hours_greenblue_day              2858 non-null   float64
#  48  tmean_24h                        3348 non-null   float64
#  49  tmean_12h                        3348 non-null   float64
#  50  humi_24h                         3348 non-null   float64
#  51  humi_12h                         3348 non-null   float64
#  52  pressure_24h                     3348 non-null   float64
#  53  pressure_12h                     3348 non-null   float64
#  54  precip_24h                       3348 non-null   float64
#  55  precip_12h                       3348 non-null   float64
#  56  precip_12h_binary                3348 non-null   int64
#  57  precip_24h_binary                3348 non-null   int64
#  58  maxwindspeed_24h                 3348 non-null   float64
#  59  maxwindspeed_12h                 3348 non-null   float64
#  60  noise_total_LDEN_55              3048 non-null   float64
#  61  access_greenbluespaces_300mbuff  3048 non-null   object
#  62  µgm3                             3018 non-null   float64
#  63  incidence_cat                    3018 non-null   object
#  64  start_year                       3018 non-null   float64
#  65  Totaltime                        3018 non-null   float64
#  66  Totaltime_estimated              3018 non-null   object
#  67  Houron                           3018 non-null   object
#  68  Houroff                          3018 non-null   object
#  69  age_yrs                          3172 non-null   float64
#  70  yearbirth                        3172 non-null   float64
#  71  smoke                            3000 non-null   object
#  72  psycho                           2964 non-null   object
#  73  gender                           3338 non-null   object
#  74  district                         3183 non-null   object
#  75  education                        3033 non-null   object
#  76  covid_work                       3313 non-null   object
#  77  covid_mood                       3174 non-null   object
#  78  covid_sleep                      3159 non-null   object
#  79  covid_espacios                   3150 non-null   object
#  80  covid_aire                       3150 non-null   object
#  81  covid_motor                      3095 non-null   object
#  82  covid_electric                   3046 non-null   object
#  83  covid_bikewalk                   3136 non-null   object
#  84  covid_public_trans               3136 non-null   object
# dtypes: float64(50), int64(6), object(29)
# memory usage: 2.2+ MB

# %%
def fun(gender):
    if gender=="Mujer":
        return 0
    return 1
df["gender_num"]=df["gender"].apply(fun).astype("int")

# %%
numerical_df=df.select_dtypes(exclude=["object"])

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 57 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Zenodo             3348 non-null   int64
#  1   date_all              3348 non-null   int64
#  2   year                  3348 non-null   int64
#  3   day                   3348 non-null   int64
#  4   occurrence_mental     3280 non-null   float64
#  5   bienestar             3273 non-null   float64
#  6   energia               3207 non-null   float64
#  7   estres                3173 non-null   float64
#  8   sueno                 3190 non-null   float64
#  9   horasfuera            3231 non-null   float64
#  10  occurrence_stroop     3046 non-null   float64
#  11  mean_incongruent      3046 non-null   float64
#  12  correct               3046 non-null   float64
#  13  response_duration_ms  3046 non-null   float64
#  14  performance           3046 non-null   float64
#  15  mean_congruent        3046 non-null   float64
#  16  inhib_control         3046 non-null   float64
#  17  z_performance         3046 non-null   float64
#  18  z_mean_incongruent    3046 non-null   float64
#  19  z_inhib_control       3046 non-null   float64
#  20  no2bcn_24h            3348 non-null   float64
#  21  no2bcn_12h            3348 non-null   float64
#  22  no2gps_24h            3151 non-null   float64
#  23  no2gps_12h            3146 non-null   float64
#  24  no2bcn_12h_x30        3348 non-null   float64
#  25  no2bcn_24h_x30        3348 non-null   float64
#  26  no2gps_12h_x30        3151 non-null   float64
#  27  no2gps_24h_x30        3151 non-null   float64
#  28  min_gps               3242 non-null   float64
#  29  hour_gps              3242 non-null   float64
#  30  pm25bcn               3348 non-null   float64
#  31  BCμg                  3068 non-null   float64
#  32  sec_noise55_day       2858 non-null   float64
#  33  sec_noise65_day       2858 non-null   float64
#  34  sec_greenblue_day     2858 non-null   float64
#  35  hours_noise_55_day    2858 non-null   float64
#  36  hours_noise_65_day    2858 non-null   float64
#  37  hours_greenblue_day   2858 non-null   float64
#  38  tmean_24h             3348 non-null   float64
#  39  tmean_12h             3348 non-null   float64
#  40  humi_24h              3348 non-null   float64
#  41  humi_12h              3348 non-null   float64
#  42  pressure_24h          3348 non-null   float64
#  43  pressure_12h          3348 non-null   float64
#  44  precip_24h            3348 non-null   float64
#  45  precip_12h            3348 non-null   float64
#  46  precip_12h_binary     3348 non-null   int64
#  47  precip_24h_binary     3348 non-null   int64
#  48  maxwindspeed_24h      3348 non-null   float64
#  49  maxwindspeed_12h      3348 non-null   float64
#  50  noise_total_LDEN_55   3048 non-null   float64
#  51  µgm3                  3018 non-null   float64
#  52  start_year            3018 non-null   float64
#  53  Totaltime             3018 non-null   float64
#  54  age_yrs               3172 non-null   float64
#  55  yearbirth             3172 non-null   float64
#  56  gender_num            3348 non-null   int64
# dtypes: float64(50), int64(7)
# memory usage: 1.5 MB

# %%
numerical_df.head()
# Out:
#    ID_Zenodo  date_all  year  day  occurrence_mental  bienestar  energia  \
# 0         71     22190  2020    2                1.0        9.0      9.0
# 1        112     22202  2020   14                2.0        8.0      9.0
# 2        110     22217  2020   29               10.0        9.0      5.0
# 3        115     22222  2020    3               14.0        3.0      2.0
# 4        135     22231  2020   12               12.0        9.0      9.0
#
#    estres  sueno  horasfuera  ...  precip_24h_binary  maxwindspeed_24h  \
# 0     1.0   10.0         7.0  ...                  1               0.4
# 1     5.0    8.0         5.0  ...                  1               2.5
# 2     8.0    9.0         8.0  ...                  0               0.0
# 3     5.0    2.0         5.0  ...                  0               0.0
# 4     6.0    2.0        22.0  ...                  0               0.0
#
#    maxwindspeed_12h  noise_total_LDEN_55   µgm3  start_year  Totaltime  \
# 0               0.4                  NaN    NaN         NaN        NaN
# 1               0.0                  0.0  19.66      2020.0     154.00
# 2               0.0                  1.0  28.48      2020.0     153.17
# 3               0.0                  1.0  15.72      2020.0     168.00
# 4               0.0                  1.0  26.66      2020.0     167.75
#
#    age_yrs  yearbirth  gender_num
# 0     49.0     1971.0           0
# 1     37.0     1983.0           0
# 2     28.0     1992.0           0
# 3     29.0     1991.0           0
# 4     33.0     1987.0           0
#
# [5 rows x 57 columns]

# %%
numerical_df.select_dtypes(include=["float"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 50 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   occurrence_mental     3280 non-null   float64
#  1   bienestar             3273 non-null   float64
#  2   energia               3207 non-null   float64
#  3   estres                3173 non-null   float64
#  4   sueno                 3190 non-null   float64
#  5   horasfuera            3231 non-null   float64
#  6   occurrence_stroop     3046 non-null   float64
#  7   mean_incongruent      3046 non-null   float64
#  8   correct               3046 non-null   float64
#  9   response_duration_ms  3046 non-null   float64
#  10  performance           3046 non-null   float64
#  11  mean_congruent        3046 non-null   float64
#  12  inhib_control         3046 non-null   float64
#  13  z_performance         3046 non-null   float64
#  14  z_mean_incongruent    3046 non-null   float64
#  15  z_inhib_control       3046 non-null   float64
#  16  no2bcn_24h            3348 non-null   float64
#  17  no2bcn_12h            3348 non-null   float64
#  18  no2gps_24h            3151 non-null   float64
#  19  no2gps_12h            3146 non-null   float64
#  20  no2bcn_12h_x30        3348 non-null   float64
#  21  no2bcn_24h_x30        3348 non-null   float64
#  22  no2gps_12h_x30        3151 non-null   float64
#  23  no2gps_24h_x30        3151 non-null   float64
#  24  min_gps               3242 non-null   float64
#  25  hour_gps              3242 non-null   float64
#  26  pm25bcn               3348 non-null   float64
#  27  BCμg                  3068 non-null   float64
#  28  sec_noise55_day       2858 non-null   float64
#  29  sec_noise65_day       2858 non-null   float64
#  30  sec_greenblue_day     2858 non-null   float64
#  31  hours_noise_55_day    2858 non-null   float64
#  32  hours_noise_65_day    2858 non-null   float64
#  33  hours_greenblue_day   2858 non-null   float64
#  34  tmean_24h             3348 non-null   float64
#  35  tmean_12h             3348 non-null   float64
#  36  humi_24h              3348 non-null   float64
#  37  humi_12h              3348 non-null   float64
#  38  pressure_24h          3348 non-null   float64
#  39  pressure_12h          3348 non-null   float64
#  40  precip_24h            3348 non-null   float64
#  41  precip_12h            3348 non-null   float64
#  42  maxwindspeed_24h      3348 non-null   float64
#  43  maxwindspeed_12h      3348 non-null   float64
#  44  noise_total_LDEN_55   3048 non-null   float64
#  45  µgm3                  3018 non-null   float64
#  46  start_year            3018 non-null   float64
#  47  Totaltime             3018 non-null   float64
#  48  age_yrs               3172 non-null   float64
#  49  yearbirth             3172 non-null   float64
# dtypes: float64(50)
# memory usage: 1.3 MB

# %%
def func(num):
    try:
        return int(num)
    except:
        return num
numerical_df[["age_yrs","yearbirth","Totaltime","start_year"]]=numerical_df[["age_yrs","yearbirth","Totaltime","start_year"]].apply(func)

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 57 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID_Zenodo             3348 non-null   int64
#  1   date_all              3348 non-null   int64
#  2   year                  3348 non-null   int64
#  3   day                   3348 non-null   int64
#  4   occurrence_mental     3280 non-null   float64
#  5   bienestar             3273 non-null   float64
#  6   energia               3207 non-null   float64
#  7   estres                3173 non-null   float64
#  8   sueno                 3190 non-null   float64
#  9   horasfuera            3231 non-null   float64
#  10  occurrence_stroop     3046 non-null   float64
#  11  mean_incongruent      3046 non-null   float64
#  12  correct               3046 non-null   float64
#  13  response_duration_ms  3046 non-null   float64
#  14  performance           3046 non-null   float64
#  15  mean_congruent        3046 non-null   float64
#  16  inhib_control         3046 non-null   float64
#  17  z_performance         3046 non-null   float64
#  18  z_mean_incongruent    3046 non-null   float64
#  19  z_inhib_control       3046 non-null   float64
#  20  no2bcn_24h            3348 non-null   float64
#  21  no2bcn_12h            3348 non-null   float64
#  22  no2gps_24h            3151 non-null   float64
#  23  no2gps_12h            3146 non-null   float64
#  24  no2bcn_12h_x30        3348 non-null   float64
#  25  no2bcn_24h_x30        3348 non-null   float64
#  26  no2gps_12h_x30        3151 non-null   float64
#  27  no2gps_24h_x30        3151 non-null   float64
#  28  min_gps               3242 non-null   float64
#  29  hour_gps              3242 non-null   float64
#  30  pm25bcn               3348 non-null   float64
#  31  BCμg                  3068 non-null   float64
#  32  sec_noise55_day       2858 non-null   float64
#  33  sec_noise65_day       2858 non-null   float64
#  34  sec_greenblue_day     2858 non-null   float64
#  35  hours_noise_55_day    2858 non-null   float64
#  36  hours_noise_65_day    2858 non-null   float64
#  37  hours_greenblue_day   2858 non-null   float64
#  38  tmean_24h             3348 non-null   float64
#  39  tmean_12h             3348 non-null   float64
#  40  humi_24h              3348 non-null   float64
#  41  humi_12h              3348 non-null   float64
#  42  pressure_24h          3348 non-null   float64
#  43  pressure_12h          3348 non-null   float64
#  44  precip_24h            3348 non-null   float64
#  45  precip_12h            3348 non-null   float64
#  46  precip_12h_binary     3348 non-null   int64
#  47  precip_24h_binary     3348 non-null   int64
#  48  maxwindspeed_24h      3348 non-null   float64
#  49  maxwindspeed_12h      3348 non-null   float64
#  50  noise_total_LDEN_55   3048 non-null   float64
#  51  µgm3                  3018 non-null   float64
#  52  start_year            3018 non-null   float64
#  53  Totaltime             3018 non-null   float64
#  54  age_yrs               3172 non-null   float64
#  55  yearbirth             3172 non-null   float64
#  56  gender_num            3348 non-null   int64
# dtypes: float64(50), int64(7)
# memory usage: 1.5 MB

# %%
numerical_df["bienestar"].describe()
# Out:
# count    3273.000000
# mean        7.220898
# std         1.657694
# min         0.000000
# 25%         6.000000
# 50%         7.000000
# 75%         8.000000
# max        10.000000
# Name: bienestar, dtype: float64

# %%
numerical_df.corr()["bienestar"].sort_values(key=abs,ascending=False).head(20)
# Out:
# bienestar              1.000000
# energia                0.678135
# sueno                  0.368086
# estres                -0.333575
# no2bcn_12h            -0.109927
# no2bcn_12h_x30        -0.109927
# no2gps_12h            -0.106531
# no2gps_24h            -0.101352
# no2gps_12h_x30        -0.101352
# no2gps_24h_x30        -0.101352
# no2bcn_24h_x30        -0.086669
# no2bcn_24h            -0.086669
# BCμg                  -0.078425
# performance            0.065045
# humi_12h              -0.064255
# µgm3                  -0.059120
# hours_greenblue_day    0.057263
# sec_greenblue_day      0.057258
# humi_24h              -0.057224
# z_performance          0.055796
# Name: bienestar, dtype: float64

# %%
sns.barplot(x=cut_into_bins(numerical_df["no2bcn_12h"],5),y=numerical_df["bienestar"])
# Out:
# [np.float64(5.238095238095238), np.float64(21.19563492063492), np.float64(37.1531746031746), np.float64(53.11071428571428), np.float64(69.06825396825396), np.float64(85.02579365079364)] duhifuhiufheufhu
# <Axes: xlabel='no2bcn_12h', ylabel='bienestar'>

# %%
numerical_df=numerical_df.drop("ID_Zenodo",axis=1)
correlation=numerical_df.corr()
correlation=correlation.reset_index()
correlation_melted=correlation.melt(id_vars="index",var_name="col",value_name="val")
correlation_melted=correlation_melted[correlation_melted["index"]!=correlation_melted["col"]]

# %%
correlation_melted.head()
# Out:
#                index       col       val
# 1               year  date_all  0.717801
# 2                day  date_all  0.053974
# 3  occurrence_mental  date_all  0.183769
# 4          bienestar  date_all  0.015560
# 5            energia  date_all  0.021038

# %%
s=set()
columns=list(numerical_df.columns)
for i in range(len(columns)):
    c1=columns[i]
    for j in range(i+1,len(columns)):
        
        s.add(c1+columns[j])

#correlation_melted=correlation_melted[(correlation_melted["index"]+correlation_melted["col"]) in s]
correlation_melted=correlation_melted[(correlation_melted["index"]+correlation_melted["col"]).isin(s)]
correlation_melted=correlation_melted.sort_values(by="val",ascending=False,key=abs)

# %%
to_print=correlation_melted.head(200)

for index in range(len(to_print)):
    row=to_print.iloc[index]
    print(row["index"],row["col"],row["val"])
# Out:
# year start_year 1.0
# mean_incongruent response_duration_ms 1.0
# no2gps_12h_x30 no2gps_24h_x30 1.0
# no2bcn_12h no2bcn_12h_x30 0.9999999999999988
# min_gps hour_gps 0.9999999999999986
# no2bcn_24h no2bcn_24h_x30 0.999999999999998
# age_yrs yearbirth -0.9999999999999978
# no2gps_24h no2gps_12h_x30 0.9999999999999978
# no2gps_24h no2gps_24h_x30 0.9999999999999978
# sec_noise55_day hours_noise_55_day 0.9976531835174688
# sec_noise65_day hours_noise_65_day 0.9970596536812448
# sec_greenblue_day hours_greenblue_day 0.9958822488786705
# pressure_24h pressure_12h 0.9863408222000367
# occurrence_mental occurrence_stroop 0.974567684523751
# tmean_24h tmean_12h 0.9683895752960392
# precip_12h maxwindspeed_12h 0.9521234488241426
# performance z_performance 0.9484271258910524
# humi_24h humi_12h 0.930906910339678
# inhib_control z_inhib_control 0.9263626335845461
# mean_incongruent z_mean_incongruent 0.9239052686653274
# response_duration_ms z_mean_incongruent 0.9239052686653274
# z_performance z_mean_incongruent -0.9042972373070909
# no2bcn_12h_x30 no2bcn_24h_x30 0.8873329227685246
# no2bcn_12h no2bcn_24h_x30 0.8873329227145229
# no2bcn_24h no2bcn_12h_x30 0.8873329202084509
# no2bcn_24h no2bcn_12h 0.8873329201544514
# no2gps_24h no2gps_12h 0.8859040865594253
# no2gps_12h no2gps_12h_x30 0.8859040844578748
# no2gps_12h no2gps_24h_x30 0.8859040844578748
# response_duration_ms performance -0.8779580072863558
# mean_incongruent performance -0.8779580072863558
# no2gps_12h no2bcn_12h_x30 0.8664594211066281
# no2bcn_12h no2gps_12h 0.8664594207981027
# no2bcn_24h no2gps_24h_x30 0.8621462680520565
# no2bcn_24h no2gps_12h_x30 0.8621462680520565
# no2bcn_24h_x30 no2gps_12h_x30 0.862146267329043
# no2bcn_24h_x30 no2gps_24h_x30 0.862146267329043
# no2bcn_24h no2gps_24h 0.8621462668116655
# no2gps_24h no2bcn_24h_x30 0.8621462660886511
# performance z_mean_incongruent -0.8573414005619054
# precip_24h maxwindspeed_24h 0.8465267722969998
# no2bcn_12h BCμg 0.8435571783879359
# no2bcn_12h_x30 BCμg 0.8435571745079207
# response_duration_ms z_performance -0.8268226850646645
# mean_incongruent z_performance -0.8268226850646645
# no2bcn_24h_x30 BCμg 0.8174145559951526
# no2bcn_24h BCμg 0.8174145475196264
# no2gps_24h no2bcn_12h_x30 0.8136643916649791
# no2bcn_12h no2gps_24h 0.8136643916082076
# no2bcn_12h_x30 no2gps_12h_x30 0.8136643906155857
# no2bcn_12h_x30 no2gps_24h_x30 0.8136643906155857
# no2bcn_12h no2gps_12h_x30 0.813664390558816
# no2bcn_12h no2gps_24h_x30 0.813664390558816
# maxwindspeed_24h maxwindspeed_12h 0.7989821431641636
# precip_12h maxwindspeed_24h 0.7567208838651507
# precip_24h precip_12h 0.7379769143980098
# date_all tmean_12h -0.7319366805883533
# no2gps_12h no2bcn_24h_x30 0.7306698427317692
# no2bcn_24h no2gps_12h 0.7306698405125424
# date_all year 0.7178005546819922
# date_all tmean_24h -0.7174271518111115
# response_duration_ms mean_congruent 0.7114099532185235
# mean_incongruent mean_congruent 0.7114099532185235
# precip_24h maxwindspeed_12h 0.7108271570880127
# no2gps_12h BCμg 0.7071004783360086
# no2gps_24h_x30 BCμg 0.7041845166482852
# no2gps_12h_x30 BCμg 0.7041845166482852
# no2gps_24h BCμg 0.7041845156933921
# pm25bcn BCμg 0.7020834482061721
# precip_12h_binary precip_24h_binary 0.6898752245128715
# bienestar energia 0.6781347206449844
# hours_noise_55_day hours_noise_65_day 0.666499597956959
# sec_noise55_day sec_noise65_day 0.6659128773409294
# sec_noise55_day hours_noise_65_day 0.6646909656226081
# sec_noise65_day hours_noise_55_day 0.6628974218164436
# hour_gps hours_noise_55_day 0.656307476028006
# min_gps hours_noise_55_day 0.6563074760280023
# hour_gps sec_noise55_day 0.6519398209539212
# min_gps sec_noise55_day 0.6519398209539204
# mean_congruent z_mean_incongruent 0.6476480707892018
# performance mean_congruent -0.6329535220997704
# date_all start_year 0.6153683930811323
# no2bcn_24h_x30 pm25bcn 0.6078791044283183
# no2bcn_24h pm25bcn 0.607879098885627
# precip_24h precip_12h_binary 0.5803265046891152
# mean_congruent z_performance -0.5769128722358952
# no2bcn_12h pm25bcn 0.5555674653966447
# no2bcn_12h_x30 pm25bcn 0.5555674627972244
# precip_12h_binary maxwindspeed_12h 0.5449291590060972
# no2gps_24h pm25bcn 0.5306989499065015
# no2gps_24h_x30 pm25bcn 0.5306989498591685
# no2gps_12h_x30 pm25bcn 0.5306989498591685
# precip_24h precip_24h_binary 0.5167772116875041
# precip_12h precip_12h_binary 0.5084793086564587
# precip_24h_binary maxwindspeed_24h 0.508310482088325
# humi_12h precip_12h_binary 0.4947981567381957
# precip_12h_binary maxwindspeed_24h 0.4915885934320027
# no2gps_12h pm25bcn 0.4893786371634411
# humi_24h precip_24h_binary 0.4785791215598688
# BCμg humi_12h 0.4733029378879986
# humi_24h precip_12h_binary 0.45735231303879115
# hour_gps hours_noise_65_day 0.4559548758738701
# min_gps hours_noise_65_day 0.4559548758738683
# hour_gps sec_noise65_day 0.4506373763488603
# min_gps sec_noise65_day 0.45063737634886025
# BCμg humi_24h 0.4453594356368883
# humi_12h precip_24h_binary 0.44166094444277265
# mean_congruent inhib_control -0.4302421644492001
# z_performance yearbirth 0.41230687737064314
# z_performance age_yrs -0.41230687737064287
# energia sueno 0.4045932800722318
# performance yearbirth 0.3898831488477438
# performance age_yrs -0.38988314884774294
# no2bcn_12h humi_12h 0.38165718609382365
# no2bcn_12h_x30 humi_12h 0.3816571856897916
# humi_24h precip_24h 0.3807092558560037
# precip_24h_binary maxwindspeed_12h 0.37593312591294287
# z_mean_incongruent yearbirth -0.36960336222562834
# z_mean_incongruent age_yrs 0.36960336222562273
# bienestar sueno 0.3680864825772331
# BCμg pressure_24h 0.3673782712595891
# mean_congruent z_inhib_control -0.3630589461785813
# z_mean_incongruent z_inhib_control 0.3608868266406701
# hour_gps hours_greenblue_day 0.36007178013223057
# min_gps hours_greenblue_day 0.3600717801322289
# hour_gps sec_greenblue_day 0.35420731162929314
# min_gps sec_greenblue_day 0.3542073116292922
# humi_12h precip_24h 0.35381073571576294
# humi_12h maxwindspeed_12h 0.3537370574197978
# no2bcn_12h humi_24h 0.3533987175530343
# no2bcn_12h_x30 humi_24h 0.35339871640317533
# precip_12h precip_24h_binary 0.3507872772195243
# humi_12h precip_12h 0.3456543996961519
# BCμg pressure_12h 0.3421184514288412
# response_duration_ms z_inhib_control 0.34129794067510694
# mean_incongruent z_inhib_control 0.34129794067510694
# pm25bcn pressure_24h 0.3401637155739266
# no2bcn_24h_x30 humi_24h 0.33747643276125244
# no2bcn_24h humi_24h 0.3374764324665269
# mean_incongruent yearbirth -0.3358868153590472
# response_duration_ms yearbirth -0.3358868153590472
# mean_incongruent age_yrs 0.3358868153590426
# response_duration_ms age_yrs 0.3358868153590426
# bienestar estres -0.3335745207191973
# pm25bcn pressure_12h 0.33049336469495444
# no2bcn_24h humi_12h 0.32903787393863776
# no2bcn_24h_x30 humi_12h 0.32903787267027795
# mean_incongruent inhib_control 0.32832796939726067
# response_duration_ms inhib_control 0.32832796939726067
# z_performance z_inhib_control -0.32687486433882595
# humi_24h maxwindspeed_24h 0.3246283700777445
# inhib_control z_mean_incongruent 0.31628350323444454
# performance z_inhib_control -0.31223813868773315
# humi_24h precip_12h 0.3105786073286842
# humi_24h pressure_24h 0.3101875519976314
# humi_12h maxwindspeed_24h 0.30917635681099803
# humi_24h maxwindspeed_12h 0.30815418568621256
# humi_12h pressure_24h 0.3060532643514686
# correct performance 0.2976528798799676
# no2bcn_24h_x30 pressure_24h 0.29740205521479074
# no2bcn_24h pressure_24h 0.29740205472160375
# occurrence_stroop performance 0.290135871770106
# year tmean_12h -0.2872163904741878
# inhib_control z_performance -0.28665270270156135
# correct z_performance 0.28205826323242117
# mean_congruent yearbirth -0.28106992026526634
# mean_congruent age_yrs 0.2810699202652614
# performance inhib_control -0.27701462450870973
# occurrence_mental performance 0.27426563507858404
# pm25bcn precip_24h_binary -0.2734641587572387
# humi_24h pressure_12h 0.2710897626096928
# no2bcn_24h_x30 pressure_12h 0.2702853238284817
# no2bcn_24h pressure_12h 0.27028532286483864
# year tmean_24h -0.26831602121764647
# humi_12h pressure_12h 0.2677607251357274
# pm25bcn precip_24h -0.2628446002038327
# occurrence_stroop response_duration_ms -0.256707093071532
# occurrence_stroop mean_incongruent -0.256707093071532
# pm25bcn maxwindspeed_24h -0.2514736664438579
# occurrence_mental pm25bcn 0.24719156103160467
# no2gps_12h_x30 humi_24h 0.24689592104796212
# no2gps_24h_x30 humi_24h 0.24689592104796212
# no2gps_24h humi_24h 0.2468959193038558
# no2gps_24h pressure_24h 0.24614713849468964
# no2gps_12h_x30 pressure_24h 0.24614713741127703
# no2gps_24h_x30 pressure_24h 0.24614713741127703
# no2gps_12h_x30 humi_12h 0.24485028979067056
# no2gps_24h_x30 humi_12h 0.24485028979067056
# no2gps_24h humi_12h 0.24485028769646056
# occurrence_stroop mean_congruent -0.24344118225483935
# no2bcn_12h_x30 pressure_24h 0.24298802214577217
# no2bcn_12h pressure_24h 0.24298801664214306
# hours_noise_55_day hours_greenblue_day 0.238860601572708
# occurrence_mental response_duration_ms -0.23872381530321862
# occurrence_mental mean_incongruent -0.23872381530321862
# sec_noise55_day sec_greenblue_day 0.23745011140512975
# sec_noise55_day hours_greenblue_day 0.2374494063387139
# sec_greenblue_day hours_noise_55_day 0.23507865172534975
# no2gps_12h humi_12h 0.23468063015275575
# date_all no2gps_12h 0.23338457779701788

# %%
columns=list(numerical_df.columns)
#numerical_df.drop(columns=["energia","estres","sueno"],inplace=True)

# %%
correlation=numerical_df.corr()
#correlation_for_filtering=correlation.copy()
#correlation["mean_corr"]=correlation.apply(lambda x:x.mean(),axis=1)
correlation=correlation.applymap(lambda x:int(x>=0.6))

correlation["corr_sum"]=correlation.apply(lambda x:x.sum(),axis=1)
# Out:
# C:\Users\shash\AppData\Local\Temp\ipykernel_5000\1788636377.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   correlation=correlation.applymap(lambda x:int(x>=0.6))

# %%
def give_columns_to_keep(df0):
    df=df0.copy()
    columns_to_remove=["corr_sum"]
    columns=df.columns.tolist()
    while True:
        index=df["corr_sum"].idxmax()
        #print(index)
        
        if df["corr_sum"][index]==1:
            columns_to_keep=[]
            for col in columns:
                if not(col in columns_to_remove):
                    columns_to_keep.append(col)
            return columns_to_keep
        df.loc[df[index]==1,"corr_sum"]-=1
        df.loc[index,"corr_sum"]=0

        columns_to_remove.append(index)
#print(correlation["corr_sum"].describe())
columns_to_keep=(give_columns_to_keep(correlation))
print(columns_to_keep)
#numerical_df=numerical_df[columns_to_keep]
# Out:
# ['day', 'energia', 'estres', 'sueno', 'horasfuera', 'occurrence_stroop', 'correct', 'z_performance', 'z_mean_incongruent', 'z_inhib_control', 'no2gps_24h_x30', 'hour_gps', 'pm25bcn', 'hours_noise_65_day', 'hours_greenblue_day', 'tmean_12h', 'humi_12h', 'pressure_12h', 'precip_24h_binary', 'maxwindspeed_12h', 'noise_total_LDEN_55', 'µgm3', 'start_year', 'Totaltime', 'age_yrs', 'yearbirth', 'gender_num']

# %%
numerical_df.corr()
# Out:
#                       date_all      year       day  occurrence_mental  \
# date_all              1.000000  0.717801  0.053974           0.183769
# year                  0.717801  1.000000  0.022716          -0.020289
# day                   0.053974  0.022716  1.000000           0.175187
# occurrence_mental     0.183769 -0.020289  0.175187           1.000000
# bienestar             0.015560  0.013027  0.044382           0.028343
# energia               0.021038  0.027011  0.034846           0.040970
# estres               -0.033756 -0.024037 -0.021136          -0.076591
# sueno                 0.006074  0.035513  0.035106           0.009943
# horasfuera           -0.036809 -0.023518 -0.030663          -0.037079
# occurrence_stroop     0.173804 -0.007847  0.150589           0.974568
# mean_incongruent      0.011005  0.097373 -0.000068          -0.238724
# correct               0.013930 -0.011617 -0.003227           0.074777
# response_duration_ms  0.011005  0.097373 -0.000068          -0.238724
# performance           0.007050 -0.103702 -0.002545           0.274266
# mean_congruent       -0.019298  0.058271 -0.006124          -0.224758
# inhib_control         0.040073  0.046756  0.008143          -0.003916
# z_performance        -0.046077 -0.107544 -0.047136          -0.008914
# z_mean_incongruent    0.056053  0.100132  0.041165           0.013855
# z_inhib_control       0.039650  0.040487  0.011413          -0.000835
# no2bcn_24h            0.133269 -0.030609  0.139856           0.215006
# no2bcn_12h            0.175094 -0.021064  0.087697           0.180429
# no2gps_24h            0.203581 -0.016697  0.112704           0.214004
# no2gps_12h            0.233385 -0.040089  0.091685           0.202193
# no2bcn_12h_x30        0.175094 -0.021064  0.087697           0.180429
# no2bcn_24h_x30        0.133269 -0.030609  0.139856           0.215006
# no2gps_12h_x30        0.203581 -0.016697  0.112704           0.214004
# no2gps_24h_x30        0.203581 -0.016697  0.112704           0.214004
# min_gps              -0.037943  0.002159 -0.000747          -0.006510
# hour_gps             -0.037943  0.002159 -0.000747          -0.006510
# pm25bcn               0.226189  0.101190  0.202024           0.247192
# BCμg                  0.139532 -0.042075  0.083083           0.208447
# sec_noise55_day      -0.042149 -0.053637  0.003561           0.018031
# sec_noise65_day      -0.075941 -0.073344  0.012567          -0.015228
# sec_greenblue_day     0.039358  0.017559  0.003460           0.009703
# hours_noise_55_day   -0.038349 -0.052675  0.004993           0.018030
# hours_noise_65_day   -0.072158 -0.072423  0.013673          -0.015229
# hours_greenblue_day   0.042633  0.018542  0.003445           0.009705
# tmean_24h            -0.717427 -0.268316  0.079141          -0.182778
# tmean_12h            -0.731937 -0.287216  0.089369          -0.154190
# humi_24h              0.208817  0.092844  0.017202           0.014974
# humi_12h              0.192735  0.092591  0.010709          -0.001171
# pressure_24h          0.061612  0.027794  0.144293           0.189083
# pressure_12h          0.061496  0.035844  0.156876           0.190585
# precip_24h           -0.062842 -0.039096  0.074934          -0.097077
# precip_12h           -0.099150 -0.015103 -0.009684          -0.052457
# precip_12h_binary     0.014513  0.037746  0.025699          -0.102680
# precip_24h_binary     0.020579  0.047645 -0.041551          -0.151771
# maxwindspeed_24h     -0.132303 -0.044248 -0.001441          -0.090448
# maxwindspeed_12h     -0.108565 -0.032750  0.019001          -0.078223
# noise_total_LDEN_55   0.006752 -0.002687  0.012610           0.028781
# µgm3                 -0.026092 -0.031181  0.022387          -0.029743
# start_year            0.615368  1.000000 -0.005116           0.004288
# Totaltime             0.002649 -0.014652  0.008710          -0.000573
# age_yrs              -0.037028  0.153460  0.000158          -0.004432
# yearbirth             0.037028 -0.153460 -0.000158           0.004432
# gender_num            0.041240  0.053666 -0.005241          -0.003176
#
#                       bienestar   energia    estres     sueno  horasfuera  \
# date_all               0.015560  0.021038 -0.033756  0.006074   -0.036809
# year                   0.013027  0.027011 -0.024037  0.035513   -0.023518
# day                    0.044382  0.034846 -0.021136  0.035106   -0.030663
# occurrence_mental      0.028343  0.040970 -0.076591  0.009943   -0.037079
# bienestar              1.000000  0.678135 -0.333575  0.368086   -0.008667
# energia                0.678135  1.000000 -0.172924  0.404593    0.027899
# estres                -0.333575 -0.172924  1.000000 -0.182543    0.116768
# sueno                  0.368086  0.404593 -0.182543  1.000000   -0.074773
# horasfuera            -0.008667  0.027899  0.116768 -0.074773    1.000000
# occurrence_stroop      0.034243  0.057276 -0.088913  0.024843   -0.029751
# mean_incongruent      -0.045678 -0.005847  0.082355 -0.036785    0.034130
# correct                0.037626  0.024338 -0.042323 -0.000411   -0.010325
# response_duration_ms  -0.045678 -0.005847  0.082355 -0.036785    0.034130
# performance            0.065045  0.001229 -0.111830  0.038480   -0.039414
# mean_congruent        -0.052319 -0.012396  0.047948 -0.053858    0.032283
# inhib_control          0.011636  0.009038  0.039490  0.024928    0.000281
# z_performance          0.055796 -0.017132 -0.088515  0.031815   -0.026061
# z_mean_incongruent    -0.039049  0.012215  0.057800 -0.025909    0.015423
# z_inhib_control       -0.001354 -0.004865  0.045425  0.015231   -0.006093
# no2bcn_24h            -0.086669 -0.073240  0.177764 -0.091894    0.076141
# no2bcn_12h            -0.109927 -0.079109  0.224393 -0.119768    0.082950
# no2gps_24h            -0.101352 -0.073719  0.187947 -0.089208    0.013931
# no2gps_12h            -0.106531 -0.061622  0.208135 -0.103003    0.023743
# no2bcn_12h_x30        -0.109927 -0.079109  0.224393 -0.119768    0.082950
# no2bcn_24h_x30        -0.086669 -0.073240  0.177764 -0.091894    0.076141
# no2gps_12h_x30        -0.101352 -0.073719  0.187947 -0.089208    0.013931
# no2gps_24h_x30        -0.101352 -0.073719  0.187947 -0.089208    0.013931
# min_gps                0.005288  0.026575 -0.035934  0.028694   -0.032093
# hour_gps               0.005288  0.026575 -0.035934  0.028694   -0.032093
# pm25bcn               -0.023516 -0.027188  0.053245 -0.041691    0.004896
# BCμg                  -0.078425 -0.070382  0.143318 -0.095298    0.064227
# sec_noise55_day       -0.013024 -0.000692  0.022322 -0.017331   -0.038170
# sec_noise65_day       -0.032009 -0.031741  0.046889 -0.016179    0.033574
# sec_greenblue_day      0.057258  0.071788 -0.010396 -0.008021    0.088585
# hours_noise_55_day    -0.013023 -0.000692  0.022322 -0.017332   -0.038169
# hours_noise_65_day    -0.032009 -0.031741  0.046889 -0.016179    0.033576
# hours_greenblue_day    0.057263  0.071803 -0.010396 -0.008005    0.088593
# tmean_24h             -0.030516 -0.029341  0.057734  0.000778    0.036066
# tmean_12h             -0.020771 -0.020337  0.043056  0.006396    0.040717
# humi_24h              -0.057224 -0.065798  0.047412 -0.039489    0.016632
# humi_12h              -0.064255 -0.062489  0.079152 -0.046099    0.032014
# pressure_24h          -0.020049 -0.005680  0.022130 -0.025226    0.021600
# pressure_12h          -0.015462  0.000763  0.017414 -0.021765    0.014118
# precip_24h             0.031479  0.001813 -0.063360  0.021183   -0.011826
# precip_12h             0.019003 -0.001684 -0.056683  0.025277   -0.003098
# precip_12h_binary     -0.007305 -0.022819 -0.036627  0.003639   -0.016295
# precip_24h_binary     -0.009737 -0.021535 -0.001089 -0.000511    0.005862
# maxwindspeed_24h       0.020367 -0.001881 -0.058539  0.013981    0.001747
# maxwindspeed_12h       0.012364 -0.000202 -0.045034  0.021261   -0.000742
# noise_total_LDEN_55   -0.041381 -0.033104 -0.014258 -0.069354    0.050387
# µgm3                  -0.059120 -0.025761  0.031930 -0.030038    0.072525
# start_year             0.018841  0.034964 -0.018132  0.044009   -0.029928
# Totaltime              0.028895  0.032537 -0.020278  0.061732   -0.034591
# age_yrs               -0.000540  0.096118  0.009838 -0.023242    0.041150
# yearbirth              0.000540 -0.096118 -0.009838  0.023242   -0.041150
# gender_num            -0.016390  0.009044 -0.047699  0.003614    0.027158
#
#                       occurrence_stroop  ...  precip_24h_binary  \
# date_all                   1.738041e-01  ...           0.020579
# year                      -7.846788e-03  ...           0.047645
# day                        1.505887e-01  ...          -0.041551
# occurrence_mental          9.745677e-01  ...          -0.151771
# bienestar                  3.424263e-02  ...          -0.009737
# energia                    5.727629e-02  ...          -0.021535
# estres                    -8.891268e-02  ...          -0.001089
# sueno                      2.484263e-02  ...          -0.000511
# horasfuera                -2.975144e-02  ...           0.005862
# occurrence_stroop          1.000000e+00  ...          -0.161413
# mean_incongruent          -2.567071e-01  ...           0.034518
# correct                    7.956327e-02  ...          -0.016255
# response_duration_ms      -2.567071e-01  ...           0.034518
# performance                2.901359e-01  ...          -0.040481
# mean_congruent            -2.434412e-01  ...           0.051944
# inhib_control             -2.543105e-03  ...          -0.025477
# z_performance             -3.602825e-10  ...           0.011547
# z_mean_incongruent        -6.515551e-11  ...          -0.011113
# z_inhib_control            5.817410e-10  ...          -0.025926
# no2bcn_24h                 1.937197e-01  ...          -0.135030
# no2bcn_12h                 1.588411e-01  ...          -0.080088
# no2gps_24h                 1.925614e-01  ...          -0.118245
# no2gps_12h                 1.816355e-01  ...          -0.099375
# no2bcn_12h_x30             1.588411e-01  ...          -0.080088
# no2bcn_24h_x30             1.937197e-01  ...          -0.135030
# no2gps_12h_x30             1.925614e-01  ...          -0.118245
# no2gps_24h_x30             1.925614e-01  ...          -0.118245
# min_gps                    7.803051e-03  ...           0.051564
# hour_gps                   7.803051e-03  ...           0.051564
# pm25bcn                    2.327730e-01  ...          -0.273464
# BCμg                       1.982872e-01  ...          -0.129717
# sec_noise55_day            8.713416e-03  ...           0.018185
# sec_noise65_day           -3.724541e-02  ...           0.007337
# sec_greenblue_day          1.931651e-02  ...          -0.014541
# hours_noise_55_day         1.383698e-02  ...           0.018418
# hours_noise_65_day        -3.198524e-02  ...           0.007193
# hours_greenblue_day        2.300352e-02  ...          -0.015833
# tmean_24h                 -1.813815e-01  ...           0.066295
# tmean_12h                 -1.504620e-01  ...          -0.037553
# humi_24h                   4.744483e-03  ...           0.478579
# humi_12h                  -1.500064e-02  ...           0.441661
# pressure_24h               1.887299e-01  ...          -0.116250
# pressure_12h               1.887315e-01  ...          -0.145786
# precip_24h                -9.586317e-02  ...           0.516777
# precip_12h                -5.046308e-02  ...           0.350787
# precip_12h_binary         -1.134950e-01  ...           0.689875
# precip_24h_binary         -1.614132e-01  ...           1.000000
# maxwindspeed_24h          -8.855949e-02  ...           0.508310
# maxwindspeed_12h          -7.719924e-02  ...           0.375933
# noise_total_LDEN_55        2.513480e-02  ...          -0.019976
# µgm3                      -3.639502e-02  ...           0.012354
# start_year                 1.120441e-02  ...           0.035687
# Totaltime                 -3.070969e-04  ...           0.017138
# age_yrs                    2.318967e-03  ...           0.022677
# yearbirth                 -2.318967e-03  ...          -0.022677
# gender_num                -4.675195e-03  ...          -0.009017
#
#                       maxwindspeed_24h  maxwindspeed_12h  noise_total_LDEN_55  \
# date_all                     -0.132303         -0.108565             0.006752
# year                         -0.044248         -0.032750            -0.002687
# day                          -0.001441          0.019001             0.012610
# occurrence_mental            -0.090448         -0.078223             0.028781
# bienestar                     0.020367          0.012364            -0.041381
# energia                      -0.001881         -0.000202            -0.033104
# estres                       -0.058539         -0.045034            -0.014258
# sueno                         0.013981          0.021261            -0.069354
# horasfuera                    0.001747         -0.000742             0.050387
# occurrence_stroop            -0.088559         -0.077199             0.025135
# mean_incongruent              0.011908          0.006260            -0.015992
# correct                       0.001492          0.004347            -0.025959
# response_duration_ms          0.011908          0.006260            -0.015992
# performance                  -0.021901         -0.013072            -0.008655
# mean_congruent                0.029095          0.022434            -0.014387
# inhib_control                -0.023809         -0.022111            -0.000932
# z_performance                 0.005675          0.010367            -0.018542
# z_mean_incongruent           -0.010553         -0.015722            -0.002263
# z_inhib_control              -0.019268         -0.021106             0.001579
# no2bcn_24h                   -0.155534         -0.080199             0.023607
# no2bcn_12h                   -0.126733         -0.065682             0.027144
# no2gps_24h                   -0.177643         -0.118761             0.027751
# no2gps_12h                   -0.157513         -0.119658             0.027752
# no2bcn_12h_x30               -0.126733         -0.065682             0.027144
# no2bcn_24h_x30               -0.155534         -0.080199             0.023607
# no2gps_12h_x30               -0.177643         -0.118761             0.027751
# no2gps_24h_x30               -0.177643         -0.118761             0.027751
# min_gps                       0.051748          0.042019             0.100682
# hour_gps                      0.051748          0.042019             0.100682
# pm25bcn                      -0.251474         -0.164866             0.027365
# BCμg                         -0.096694         -0.031787             0.030273
# sec_noise55_day               0.020995          0.005779             0.175635
# sec_noise65_day               0.014355          0.008991             0.093037
# sec_greenblue_day            -0.014884         -0.007704             0.064047
# hours_noise_55_day            0.020827          0.006575             0.175075
# hours_noise_65_day            0.013936          0.009829             0.092479
# hours_greenblue_day          -0.016119         -0.006906             0.062924
# tmean_24h                     0.124449          0.156298            -0.001543
# tmean_12h                     0.034689          0.057035            -0.001384
# humi_24h                      0.324628          0.308154             0.006179
# humi_12h                      0.309176          0.353737             0.012663
# pressure_24h                  0.012341          0.010512             0.005491
# pressure_12h                 -0.003295         -0.001067             0.002842
# precip_24h                    0.846527          0.710827            -0.013703
# precip_12h                    0.756721          0.952123            -0.010327
# precip_12h_binary             0.491589          0.544929            -0.003276
# precip_24h_binary             0.508310          0.375933            -0.019976
# maxwindspeed_24h              1.000000          0.798982            -0.014384
# maxwindspeed_12h              0.798982          1.000000            -0.011187
# noise_total_LDEN_55          -0.014384         -0.011187             1.000000
# µgm3                         -0.005124         -0.008757             0.088969
# start_year                   -0.030634         -0.023931             0.025790
# Totaltime                     0.007557          0.007939             0.041624
# age_yrs                       0.018513          0.018119             0.037032
# yearbirth                    -0.018513         -0.018119            -0.037032
# gender_num                   -0.023733         -0.016552             0.019733
#
#                           µgm3  start_year  Totaltime   age_yrs  yearbirth  \
# date_all             -0.026092    0.615368   0.002649 -0.037028   0.037028
# year                 -0.031181    1.000000  -0.014652  0.153460  -0.153460
# day                   0.022387   -0.005116   0.008710  0.000158  -0.000158
# occurrence_mental    -0.029743    0.004288  -0.000573 -0.004432   0.004432
# bienestar            -0.059120    0.018841   0.028895 -0.000540   0.000540
# energia              -0.025761    0.034964   0.032537  0.096118  -0.096118
# estres                0.031930   -0.018132  -0.020278  0.009838  -0.009838
# sueno                -0.030038    0.044009   0.061732 -0.023242   0.023242
# horasfuera            0.072525   -0.029928  -0.034591  0.041150  -0.041150
# occurrence_stroop    -0.036395    0.011204  -0.000307  0.002319  -0.002319
# mean_incongruent      0.101221    0.136360  -0.007615  0.335887  -0.335887
# correct               0.045748   -0.001097  -0.000716  0.011860  -0.011860
# response_duration_ms  0.101221    0.136360  -0.007615  0.335887  -0.335887
# performance          -0.107669   -0.158501   0.004421 -0.389883   0.389883
# mean_congruent        0.094571    0.085072  -0.014876  0.281070  -0.281070
# inhib_control        -0.000848    0.054851   0.010332  0.052861  -0.052861
# z_performance        -0.104089   -0.169902   0.005332 -0.412307   0.412307
# z_mean_incongruent    0.102869    0.153541  -0.007929  0.369603  -0.369603
# z_inhib_control       0.006949    0.048757   0.005173  0.033561  -0.033561
# no2bcn_24h            0.016625   -0.012204  -0.025555 -0.046454   0.046454
# no2bcn_12h            0.017325   -0.005034  -0.018280 -0.050592   0.050592
# no2gps_24h            0.041198    0.002141  -0.013298 -0.071115   0.071115
# no2gps_12h            0.039030   -0.019092  -0.016314 -0.082608   0.082608
# no2bcn_12h_x30        0.017325   -0.005034  -0.018280 -0.050592   0.050592
# no2bcn_24h_x30        0.016625   -0.012204  -0.025555 -0.046454   0.046454
# no2gps_12h_x30        0.041198    0.002141  -0.013298 -0.071115   0.071115
# no2gps_24h_x30        0.041198    0.002141  -0.013298 -0.071115   0.071115
# min_gps               0.011289    0.026438  -0.000418  0.035478  -0.035478
# hour_gps              0.011289    0.026438  -0.000418  0.035478  -0.035478
# pm25bcn               0.032298    0.099829  -0.042563  0.015927  -0.015927
# BCμg                  0.026241   -0.022651  -0.030949 -0.034687   0.034687
# sec_noise55_day       0.049106   -0.038088   0.054510 -0.064589   0.064589
# sec_noise65_day       0.109605   -0.063171  -0.009142 -0.005442   0.005442
# sec_greenblue_day    -0.059331    0.052685  -0.010019 -0.003455   0.003455
# hours_noise_55_day    0.049275   -0.037709   0.053358 -0.066798   0.066798
# hours_noise_65_day    0.109626   -0.062736  -0.010132 -0.007928   0.007928
# hours_greenblue_day  -0.055476    0.053123  -0.011218 -0.004940   0.004940
# tmean_24h             0.031149   -0.210634  -0.024724  0.129632  -0.129632
# tmean_12h             0.032022   -0.224668  -0.024102  0.128704  -0.128704
# humi_24h              0.030118    0.075304  -0.038962 -0.015601   0.015601
# humi_12h              0.025861    0.071901  -0.032065 -0.014530   0.014530
# pressure_24h          0.038888   -0.032548  -0.035637  0.114492  -0.114492
# pressure_12h          0.035399   -0.031867  -0.036900  0.118592  -0.118592
# precip_24h            0.003120   -0.028730  -0.006685 -0.010975   0.010975
# precip_12h           -0.007837   -0.009726   0.008831  0.025066  -0.025066
# precip_12h_binary     0.011304    0.017691   0.007492 -0.004541   0.004541
# precip_24h_binary     0.012354    0.035687   0.017138  0.022677  -0.022677
# maxwindspeed_24h     -0.005124   -0.030634   0.007557  0.018513  -0.018513
# maxwindspeed_12h     -0.008757   -0.023931   0.007939  0.018119  -0.018119
# noise_total_LDEN_55   0.088969    0.025790   0.041624  0.037032  -0.037032
# µgm3                  1.000000   -0.031181  -0.125113  0.089539  -0.089539
# start_year           -0.031181    1.000000  -0.014652  0.182671  -0.182671
# Totaltime            -0.125113   -0.014652   1.000000 -0.017694   0.017694
# age_yrs               0.089539    0.182671  -0.017694  1.000000  -1.000000
# yearbirth            -0.089539   -0.182671   0.017694 -1.000000   1.000000
# gender_num            0.048805    0.004165  -0.125595  0.061919  -0.061919
#
#                       gender_num
# date_all                0.041240
# year                    0.053666
# day                    -0.005241
# occurrence_mental      -0.003176
# bienestar              -0.016390
# energia                 0.009044
# estres                 -0.047699
# sueno                   0.003614
# horasfuera              0.027158
# occurrence_stroop      -0.004675
# mean_incongruent        0.024573
# correct                -0.020098
# response_duration_ms    0.024573
# performance            -0.029146
# mean_congruent          0.006469
# inhib_control           0.022870
# z_performance          -0.029548
# z_mean_incongruent      0.021970
# z_inhib_control         0.015796
# no2bcn_24h             -0.004370
# no2bcn_12h             -0.014870
# no2gps_24h             -0.018977
# no2gps_12h             -0.017931
# no2bcn_12h_x30         -0.014870
# no2bcn_24h_x30         -0.004370
# no2gps_12h_x30         -0.018977
# no2gps_24h_x30         -0.018977
# min_gps                -0.003460
# hour_gps               -0.003460
# pm25bcn                 0.015054
# BCμg                    0.000058
# sec_noise55_day        -0.003381
# sec_noise65_day        -0.007204
# sec_greenblue_day      -0.078908
# hours_noise_55_day     -0.004284
# hours_noise_65_day     -0.007010
# hours_greenblue_day    -0.081583
# tmean_24h              -0.040012
# tmean_12h              -0.034571
# humi_24h               -0.009633
# humi_12h               -0.006430
# pressure_24h            0.028695
# pressure_12h            0.029247
# precip_24h             -0.023223
# precip_12h             -0.013104
# precip_12h_binary      -0.003004
# precip_24h_binary      -0.009017
# maxwindspeed_24h       -0.023733
# maxwindspeed_12h       -0.016552
# noise_total_LDEN_55     0.019733
# µgm3                    0.048805
# start_year              0.004165
# Totaltime              -0.125595
# age_yrs                 0.061919
# yearbirth              -0.061919
# gender_num              1.000000
#
# [56 rows x 56 columns]

# %%
numerical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3348 entries, 0 to 3347
# Data columns (total 56 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              3348 non-null   int64
#  1   year                  3348 non-null   int64
#  2   day                   3348 non-null   int64
#  3   occurrence_mental     3280 non-null   float64
#  4   bienestar             3273 non-null   float64
#  5   energia               3207 non-null   float64
#  6   estres                3173 non-null   float64
#  7   sueno                 3190 non-null   float64
#  8   horasfuera            3231 non-null   float64
#  9   occurrence_stroop     3046 non-null   float64
#  10  mean_incongruent      3046 non-null   float64
#  11  correct               3046 non-null   float64
#  12  response_duration_ms  3046 non-null   float64
#  13  performance           3046 non-null   float64
#  14  mean_congruent        3046 non-null   float64
#  15  inhib_control         3046 non-null   float64
#  16  z_performance         3046 non-null   float64
#  17  z_mean_incongruent    3046 non-null   float64
#  18  z_inhib_control       3046 non-null   float64
#  19  no2bcn_24h            3348 non-null   float64
#  20  no2bcn_12h            3348 non-null   float64
#  21  no2gps_24h            3151 non-null   float64
#  22  no2gps_12h            3146 non-null   float64
#  23  no2bcn_12h_x30        3348 non-null   float64
#  24  no2bcn_24h_x30        3348 non-null   float64
#  25  no2gps_12h_x30        3151 non-null   float64
#  26  no2gps_24h_x30        3151 non-null   float64
#  27  min_gps               3242 non-null   float64
#  28  hour_gps              3242 non-null   float64
#  29  pm25bcn               3348 non-null   float64
#  30  BCμg                  3068 non-null   float64
#  31  sec_noise55_day       2858 non-null   float64
#  32  sec_noise65_day       2858 non-null   float64
#  33  sec_greenblue_day     2858 non-null   float64
#  34  hours_noise_55_day    2858 non-null   float64
#  35  hours_noise_65_day    2858 non-null   float64
#  36  hours_greenblue_day   2858 non-null   float64
#  37  tmean_24h             3348 non-null   float64
#  38  tmean_12h             3348 non-null   float64
#  39  humi_24h              3348 non-null   float64
#  40  humi_12h              3348 non-null   float64
#  41  pressure_24h          3348 non-null   float64
#  42  pressure_12h          3348 non-null   float64
#  43  precip_24h            3348 non-null   float64
#  44  precip_12h            3348 non-null   float64
#  45  precip_12h_binary     3348 non-null   int64
#  46  precip_24h_binary     3348 non-null   int64
#  47  maxwindspeed_24h      3348 non-null   float64
#  48  maxwindspeed_12h      3348 non-null   float64
#  49  noise_total_LDEN_55   3048 non-null   float64
#  50  µgm3                  3018 non-null   float64
#  51  start_year            3018 non-null   float64
#  52  Totaltime             3018 non-null   float64
#  53  age_yrs               3172 non-null   float64
#  54  yearbirth             3172 non-null   float64
#  55  gender_num            3348 non-null   int64
# dtypes: float64(50), int64(6)
# memory usage: 1.4 MB

# %%
numerical_df=numerical_df.dropna()
columns=["sueno","estres","energia","bienestar"]
numerical_df.boxplot(column=columns)
numerical_df=remove_outliers_iqr(numerical_df,columns)

# %%
scaler=StandardScaler()


#clustering_df=.drop("bienestar",axis=1)
#scaler_target=StandardScaler()
"""
numerical_df["bienestar"]=cut_into_bins(numerical_df["bienestar"],3)
numerical_df["energia"]=cut_into_bins(numerical_df["energia"],3)
numerical_df["estres"]=cut_into_bins(numerical_df["estres"],3)
numerical_df["sueno"]=cut_into_bins(numerical_df["sueno"],3)
"""
scaler1=StandardScaler()
scaler_bienestar=StandardScaler()
#energia
scaler_energia=StandardScaler()
#estres
scaler_estres=StandardScaler()
#sueno
scaler_sueno=StandardScaler()
#Scaled=pd.DataFrame(scaler.fit_transform(clustering_df.drop("bienestar",axis=1)),columns=clustering_df.drop("bienestar",axis=1).columns,index=clustering_df.index)
#Scaled=pd.concat([Scaled,pd.DataFrame(scaler_target.fit_transform(clustering_df[["bienestar"]]),columns=["bienestar"])],axis=1)
#X_scaled["bienestar"]=X_scaled["bienestar"]*10
Scaled_x=numerical_df.drop(["bienestar","energia","estres","sueno"],axis=1)
Scaled_x=pd.DataFrame(scaler1.fit_transform(Scaled_x),columns=Scaled_x.columns)
Scaled_y_bienestar=pd.DataFrame(scaler_bienestar.fit_transform(numerical_df[["bienestar"]]),columns=["bienestar"])
Scaled_y_sueno=pd.DataFrame(scaler_sueno.fit_transform(numerical_df[["sueno"]]),columns=["sueno"])
Scaled_y_energia=pd.DataFrame(scaler_energia.fit_transform(numerical_df[["energia"]]),columns=["energia"])
Scaled_y_estres=pd.DataFrame(scaler_estres.fit_transform(numerical_df[["estres"]]),columns=["estres"])
Scaled=pd.concat([Scaled_x,Scaled_y_bienestar,
                 Scaled_y_sueno,Scaled_y_energia,Scaled_y_estres],axis=1)

# %%
Scaled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1706 entries, 0 to 1705
# Data columns (total 56 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1706 non-null   float64
#  1   year                  1706 non-null   float64
#  2   day                   1706 non-null   float64
#  3   occurrence_mental     1706 non-null   float64
#  4   horasfuera            1706 non-null   float64
#  5   occurrence_stroop     1706 non-null   float64
#  6   mean_incongruent      1706 non-null   float64
#  7   correct               1706 non-null   float64
#  8   response_duration_ms  1706 non-null   float64
#  9   performance           1706 non-null   float64
#  10  mean_congruent        1706 non-null   float64
#  11  inhib_control         1706 non-null   float64
#  12  z_performance         1706 non-null   float64
#  13  z_mean_incongruent    1706 non-null   float64
#  14  z_inhib_control       1706 non-null   float64
#  15  no2bcn_24h            1706 non-null   float64
#  16  no2bcn_12h            1706 non-null   float64
#  17  no2gps_24h            1706 non-null   float64
#  18  no2gps_12h            1706 non-null   float64
#  19  no2bcn_12h_x30        1706 non-null   float64
#  20  no2bcn_24h_x30        1706 non-null   float64
#  21  no2gps_12h_x30        1706 non-null   float64
#  22  no2gps_24h_x30        1706 non-null   float64
#  23  min_gps               1706 non-null   float64
#  24  hour_gps              1706 non-null   float64
#  25  pm25bcn               1706 non-null   float64
#  26  BCμg                  1706 non-null   float64
#  27  sec_noise55_day       1706 non-null   float64
#  28  sec_noise65_day       1706 non-null   float64
#  29  sec_greenblue_day     1706 non-null   float64
#  30  hours_noise_55_day    1706 non-null   float64
#  31  hours_noise_65_day    1706 non-null   float64
#  32  hours_greenblue_day   1706 non-null   float64
#  33  tmean_24h             1706 non-null   float64
#  34  tmean_12h             1706 non-null   float64
#  35  humi_24h              1706 non-null   float64
#  36  humi_12h              1706 non-null   float64
#  37  pressure_24h          1706 non-null   float64
#  38  pressure_12h          1706 non-null   float64
#  39  precip_24h            1706 non-null   float64
#  40  precip_12h            1706 non-null   float64
#  41  precip_12h_binary     1706 non-null   float64
#  42  precip_24h_binary     1706 non-null   float64
#  43  maxwindspeed_24h      1706 non-null   float64
#  44  maxwindspeed_12h      1706 non-null   float64
#  45  noise_total_LDEN_55   1706 non-null   float64
#  46  µgm3                  1706 non-null   float64
#  47  start_year            1706 non-null   float64
#  48  Totaltime             1706 non-null   float64
#  49  age_yrs               1706 non-null   float64
#  50  yearbirth             1706 non-null   float64
#  51  gender_num            1706 non-null   float64
#  52  bienestar             1706 non-null   float64
#  53  sueno                 1706 non-null   float64
#  54  energia               1706 non-null   float64
#  55  estres                1706 non-null   float64
# dtypes: float64(56)
# memory usage: 746.5 KB

# %%
silhouette_scores = []
k_values = range(2, 11) # Start from 2, as a silhouette score is not defined for k=1

for k in k_values:
    # Apply K-Means
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(Scaled)

    # Get the cluster labels for each data point
    labels = kmeans.labels_

    # Calculate the silhouette score
    score = silhouette_score(Scaled, labels)
    silhouette_scores.append(score)

    print(f"For k={k}, the silhouette score is: {score:.4f}")
# Out:
# For k=2, the silhouette score is: 0.1098
# For k=3, the silhouette score is: 0.1137
# For k=4, the silhouette score is: 0.1077
# For k=5, the silhouette score is: 0.1093
# For k=6, the silhouette score is: 0.1056
# For k=7, the silhouette score is: 0.1111
# For k=8, the silhouette score is: 0.0893
# For k=9, the silhouette score is: 0.0931
# For k=10, the silhouette score is: 0.0909

# %%
plt.figure(figsize=(10, 6))
plt.plot(k_values, silhouette_scores, marker='o', linestyle='--')
plt.title('Silhouette Scores for Different Number of Clusters')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Average Silhouette Score')
plt.xticks(k_values)
plt.grid(True)
plt.show()

# Find the optimal k value
optimal_k_index = np.argmax(silhouette_scores)
optimal_k = k_values[optimal_k_index]

print(f"\n The optimal number of clusters (k) is approximately: {optimal_k}")
# Out:
#  The optimal number of clusters (k) is approximately: 3

# %%
#lof = LocalOutlierFactor(n_neighbors=2, contamination=0.1)

# Fit the model and get the outlier labels.
# -1 indicates an outlier, and 1 indicates an inlier.
#outlier_labels = lof.fit_predict(Scaled)

# Step 3: Add the labels to the DataFrame and filter
#Scaled['outlier_label'] = outlier_labels

# Filter out the rows identified as outliers
Scaled_clean = Scaled.copy()
estres=Scaled_clean[["estres"]]
energia=Scaled_clean[["energia"]]
sueno=Scaled_clean[["sueno"]]
bienestar=Scaled_clean[["bienestar"]]
#Scaled_clean.drop(["outlier_label"],axis=1,inplace=True)
print("Original DataFrame (with labels):")
print(len(Scaled))

print("\nCleaned DataFrame (outliers removed):")
print(len(Scaled_clean))
# Out:
# Original DataFrame (with labels):
# 1706
#
# Cleaned DataFrame (outliers removed):
# 1706

# %%
pca = PCA()
pca.fit(Scaled_clean)

# Step 4: Calculate the cumulative explained variance
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

# Step 5: Plot the explained variance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o', linestyle='--')
plt.title('Explained Variance Plot')
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.axhline(y=0.95, color='r', linestyle='-', label='95% Explained Variance Threshold')
plt.legend(loc='lower right')
plt.show()

# %%
Scaled_clean.drop(["bienestar","energia","estres","sueno"],axis=1,inplace=True)

# %%
X=Scaled_clean
Y=pd.DataFrame(scaler_bienestar.inverse_transform(bienestar),columns=["bienestar"])

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    Y, 
    test_size=0.2, 
    random_state=42
)

# %%
model = LinearRegression()

# Train model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# %%
print(y_test.describe())
# Out:
#         bienestar
# count  342.000000
# mean     7.441520
# std      1.406239
# min      3.000000
# 25%      7.000000
# 50%      8.000000
# 75%      8.000000
# max     10.000000

# %%
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 1.2672
# R-squared (R2): -2.8775

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 7.65
# Root Mean Squared Error: 2.77

# %%
# Initialize the XGBoost Regressor model
xgb_regressor = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42
)


# Train the model on the training data
xgb_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
# Make predictions on the test set
y_pred = xgb_regressor.predict(X_test)

# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

print(f"Mean Squared Error: {mse:.2f}")
print(f"Root Mean Squared Error: {rmse:.2f}")
# Out:
# Mean Squared Error: 1.74
# Root Mean Squared Error: 1.32

# %%
print(y_test.describe())
# Out:
#         bienestar
# count  342.000000
# mean     7.441520
# std      1.406239
# min      3.000000
# 25%      7.000000
# 50%      8.000000
# 75%      8.000000
# max     10.000000

# %%
"""
X=X[["day","dayoftheweek","horasfuera","correct","no2gps_24h_x30","hours_greenblue_day",
    "humi_12h","end_day","end_year","end_hour"]]
"""
# Out:
# '\nX=X[["day","dayoftheweek","horasfuera","correct","no2gps_24h_x30","hours_greenblue_day",\n    "humi_12h","end_day","end_year","end_hour"]]\n'

# %%
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 1.0362
# R-squared (R2): 0.1178

# %%
plot_importance(xgb_regressor, importance_type="gain")
plt.show()

# %%
explainer = shap.TreeExplainer(xgb_regressor)
shap_values = explainer.shap_values(X_train)


shap.summary_plot(shap_values, X_train)

# %%
print(max(xgb_regressor.feature_importances_))
# Out:
# 0.08066486

# %%
booster = xgb_regressor.get_booster()

# Importance types: "weight", "gain", "cover", "total_gain", "total_cover"
importance = booster.get_score(importance_type="gain")

print(importance)
print(len(importance))
# Out:
# {'date_all': 3.0810394287109375, 'day': 2.6621227264404297, 'occurrence_mental': 1.9762332439422607, 'horasfuera': 3.424468994140625, 'occurrence_stroop': 3.0198092460632324, 'mean_incongruent': 3.3175389766693115, 'correct': 5.239040374755859, 'performance': 5.110058307647705, 'mean_congruent': 4.433074474334717, 'inhib_control': 4.19717264175415, 'z_performance': 4.681358814239502, 'z_mean_incongruent': 5.284268856048584, 'z_inhib_control': 6.23621129989624, 'no2bcn_24h': 4.497766971588135, 'no2bcn_12h': 8.195897102355957, 'no2gps_24h': 4.5544915199279785, 'no2gps_12h': 6.885500431060791, 'min_gps': 4.929139137268066, 'pm25bcn': 3.9061214923858643, 'BCμg': 5.151525497436523, 'sec_noise55_day': 4.6361775398254395, 'sec_noise65_day': 7.031861782073975, 'sec_greenblue_day': 6.445185661315918, 'tmean_24h': 5.628452301025391, 'tmean_12h': 5.58687162399292, 'humi_24h': 5.876498699188232, 'humi_12h': 3.9047136306762695, 'pressure_24h': 5.972114562988281, 'pressure_12h': 7.740589141845703, 'precip_24h': 5.988708019256592, 'precip_12h': 7.625161170959473, 'maxwindspeed_24h': 17.4047794342041, 'noise_total_LDEN_55': 5.448060989379883, 'µgm3': 11.352113723754883, 'Totaltime': 9.482375144958496, 'age_yrs': 9.362649917602539, 'gender_num': 5.497411251068115}
# 37

# %%
print(len(X_train.columns))
# Out:
# 52

# %%
sorted_by_value = sorted(importance.items(), key=lambda item: item[1])

# %%
important_columns=[i for i in importance]
#important_columns=important_columns[:int(len(important_columns)*0.10)]
print(important_columns)
#X_train=X_train[important_columns]
#X_test=X_test[important_columns]
# Out:
# ['date_all', 'day', 'occurrence_mental', 'horasfuera', 'occurrence_stroop', 'mean_incongruent', 'correct', 'performance', 'mean_congruent', 'inhib_control', 'z_performance', 'z_mean_incongruent', 'z_inhib_control', 'no2bcn_24h', 'no2bcn_12h', 'no2gps_24h', 'no2gps_12h', 'min_gps', 'pm25bcn', 'BCμg', 'sec_noise55_day', 'sec_noise65_day', 'sec_greenblue_day', 'tmean_24h', 'tmean_12h', 'humi_24h', 'humi_12h', 'pressure_24h', 'pressure_12h', 'precip_24h', 'precip_12h', 'maxwindspeed_24h', 'noise_total_LDEN_55', 'µgm3', 'Totaltime', 'age_yrs', 'gender_num']

# %%
# Initialize the XGBoost Regressor model
xgb_regressor = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42
)


# Train the model on the training data
xgb_regressor.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred = xgb_regressor.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 1.0362
# R-squared (R2): 0.1178

# %%
Y=pd.DataFrame(scaler_estres.inverse_transform(estres),columns=["estres"])
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    Y, 
    test_size=0.2, 
    random_state=42
)
xgb_regressor = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    random_state=42
)


# Train the model on the training data
xgb_regressor.fit(X_train, y_train)
y_pred = xgb_regressor.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"R-squared (R2): {r2:.4f}")
# Out:
# Mean Absolute Error (MAE): 1.5822
# R-squared (R2): 0.2619

# %%
scaler_estres.inverse_transform(estres).max()
# Out:
# np.float64(10.0)

# %%
scalers={"sueno":scaler_sueno,"estres":scaler_estres,"energia":scaler_energia,
         "bienestar":scaler_bienestar}

# %%
column_to_predict="sueno"
mid_value=7

# %%
to_inverse_transform={"estres":estres,"sueno":sueno,"energia":energia,"bienestar":bienestar}
Y=pd.DataFrame(scalers[column_to_predict].inverse_transform(to_inverse_transform[column_to_predict]),columns=[column_to_predict])
Y.info()
Y[column_to_predict]=cut_into_bins(Y[column_to_predict],2,bin_vertices=[-1,mid_value,11]).astype("int")

#Y.info()

#Y["estres"]=cut_into_bins/(Y["estres"],3).astype("int").astype("category")

X_train, X_test, y_train, y_test = train_test_split(
    X, 
    Y, 
    test_size=0.2, 
    random_state=42
)

weights=[1,1]
X_train_resampled, y_train_resampled = oversampling(X_train,y_train,2,weights)
#X_train_resampled,y_train_resampled=X_train,y_train
model = xgb.XGBClassifier(
    n_estimators=100,     # Number of boosting rounds (trees)
    learning_rate=0.1,    # Step size
    max_depth=10,          # Depth of trees
    use_label_encoder=False, # Avoids warning
    eval_metric="mlogloss",  # Multi-class log loss
    random_state=42,
    enable_categorical=True,
    scale_pos_weight=4.5538
)

# Train model
model.fit(X_train_resampled, y_train_resampled)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1706 entries, 0 to 1705
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sueno   1706 non-null   float64
# dtypes: float64(1)
# memory usage: 13.5 KB
# [np.float64(3.0), np.float64(6.5), np.float64(10.0)] duhifuhiufheufhu
# <class 'pandas.core.frame.DataFrame'>
# Index: 1364 entries, 590 to 1126
# Data columns (total 53 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date_all              1364 non-null   float64
#  1   year                  1364 non-null   float64
#  2   day                   1364 non-null   float64
#  3   occurrence_mental     1364 non-null   float64
#  4   horasfuera            1364 non-null   float64
#  5   occurrence_stroop     1364 non-null   float64
#  6   mean_incongruent      1364 non-null   float64
#  7   correct               1364 non-null   float64
#  8   response_duration_ms  1364 non-null   float64
#  9   performance           1364 non-null   float64
#  10  mean_congruent        1364 non-null   float64
#  11  inhib_control         1364 non-null   float64
#  12  z_performance         1364 non-null   float64
#  13  z_mean_incongruent    1364 non-null   float64
#  14  z_inhib_control       1364 non-null   float64
#  15  no2bcn_24h            1364 non-null   float64
#  16  no2bcn_12h            1364 non-null   float64
#  17  no2gps_24h            1364 non-null   float64
#  18  no2gps_12h            1364 non-null   float64
#  19  no2bcn_12h_x30        1364 non-null   float64
#  20  no2bcn_24h_x30        1364 non-null   float64
#  21  no2gps_12h_x30        1364 non-null   float64
#  22  no2gps_24h_x30        1364 non-null   float64
#  23  min_gps               1364 non-null   float64
#  24  hour_gps              1364 non-null   float64
#  25  pm25bcn               1364 non-null   float64
#  26  BCμg                  1364 non-null   float64
#  27  sec_noise55_day       1364 non-null   float64
#  28  sec_noise65_day       1364 non-null   float64
#  29  sec_greenblue_day     1364 non-null   float64
#  30  hours_noise_55_day    1364 non-null   float64
#  31  hours_noise_65_day    1364 non-null   float64
#  32  hours_greenblue_day   1364 non-null   float64
#  33  tmean_24h             1364 non-null   float64
#  34  tmean_12h             1364 non-null   float64
#  35  humi_24h              1364 non-null   float64
#  36  humi_12h              1364 non-null   float64
#  37  pressure_24h          1364 non-null   float64
#  38  pressure_12h          1364 non-null   float64
#  39  precip_24h            1364 non-null   float64
#  40  precip_12h            1364 non-null   float64
#  41  precip_12h_binary     1364 non-null   float64
#  42  precip_24h_binary     1364 non-null   float64
#  43  maxwindspeed_24h      1364 non-null   float64
#  44  maxwindspeed_12h      1364 non-null   float64
#  45  noise_total_LDEN_55   1364 non-null   float64
#  46  µgm3                  1364 non-null   float64
#  47  start_year            1364 non-null   float64
#  48  Totaltime             1364 non-null   float64
#  49  age_yrs               1364 non-null   float64
#  50  yearbirth             1364 non-null   float64
#  51  gender_num            1364 non-null   float64
#  52  sueno                 1364 non-null   int64
# dtypes: float64(52), int64(1)
# memory usage: 575.4 KB
# C:\Users\shash\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\training.py:183: UserWarning: [22:42:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
together=pd.concat([X_test,y_test],axis=1)
min_length=min(len(y_test[y_test[column_to_predict]==0]),len(y_test[y_test[column_to_predict]==1]))
X1_sample = together[together[column_to_predict]==1]
X0_sample=together[together[column_to_predict]==0].sample(n=min_length, random_state=42,replace=False)
X_sample=pd.concat([X1_sample,X0_sample]).sample(n=min_length, random_state=42,replace=False)
Y_sample=X_sample[column_to_predict]
X_sample.drop(columns=[column_to_predict],axis=1,inplace=True)
y_pred = model.predict(X_sample)


# y_true: true binary labels (0 or 1)
# y_scores: model's predicted probabilities or decision function values
y_scores = model.predict_proba(X_sample)[:, 1]
precision, recall, thresholds = precision_recall_curve(Y_sample, y_scores)

# Method 1: Standard AUC of the PR curve
auc_pr = auc(recall, precision)

# Method 2: Average Precision (AP), more common in ML papers
ap_score = average_precision_score(Y_sample, y_pred)

print("AUC-PR:", auc_pr)
print("Average Precision (AP):", ap_score)
print("Accuracy:", accuracy_score(Y_sample, y_pred))
print("\nClassification Report:\n", classification_report(Y_sample, y_pred))


cm = confusion_matrix(Y_sample, y_pred)

# Display
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap="Blues", values_format='d')
plt.show()
cm = confusion_matrix(Y_sample, y_pred)
# Out:
# AUC-PR: 0.5992783190867137
# Average Precision (AP): 0.5386757208157524
# Accuracy: 0.5569620253164557
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57        78
#            1       0.57      0.51      0.54        80
#
#     accuracy                           0.56       158
#    macro avg       0.56      0.56      0.56       158
# weighted avg       0.56      0.56      0.56       158

# %%
xgb.plot_importance(model, importance_type='gain')
plt.show()
